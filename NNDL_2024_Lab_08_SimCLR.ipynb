# %% [markdown]
# <a href="https://colab.research.google.com/github/albertomors/nndeep/blob/main/NNDL_2024_Lab_08_SimCLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NEURAL NETWORKS AND DEEP LEARNING
#
# ---
# A.A. 2023/24 (6 CFU) - Dr. Jacopo Pegoraro,  Dr. Riccardo Mazzieri, Dr. Daniele Mari
# ---
#
# ## Lab. 08 - Self Supervised Learning
#
# This notebook is an adaptation of this tutorial provided by Google Research: https://colab.research.google.com/github/phlippe/uvadlc_notebooks/blob/master/docs/tutorial_notebooks/tutorial17/SimCLR.ipynb
#
# Here, the authors implement and train all the models with PyTorch Lightning, while we will use vanilla PyTorch instead. Feel free to check this out if you are interested.

# %% [markdown]
# In this Laboratory class, we will implement an example of *self-supervised contrastive learning*.
#
# Self-supervised learning, describes the scenario where we have given input data, but no accompanying labels to train in a classical supervised way. However, this data still contains a lot of information from which we can learn: how are the images different from each other? What patterns are descriptive for certain images? Can we cluster the images? And so on. Methods for self-supervised learning try to learn as much as possible from the data alone, so it can quickly be finetuned for a specific classification task.
# The benefit of self-supervised learning is that a large dataset can often easily be obtained. For instance, if we want to train a vision model on semantic segmentation for autonomous driving, we can collect large amounts of data by simply installing a camera in a car, and driving through a city for an hour. In contrast, if we would want to do supervised learning, we would have to manually label all those images before training a model. This is extremely expensive, and would likely take a couple of months to manually label the same amount of data. Further, self-supervised learning can provide an alternative to transfer learning from models pretrained on ImageNet since we could pretrain a model on a specific dataset/situation, e.g. traffic scenarios for autonomous driving.
#
# Within the last two years, a lot of new approaches have been proposed for self-supervised learning, in particular for images, that have resulted in great improvements over supervised models when few labels are available. The subfield that we will focus on in this tutorial is contrastive learning. Contrastive learning is motivated by the question mentioned above: how are images different from each other? Specifically, contrastive learning methods train a model to cluster an image and its slightly augmented version in latent space, while the distance to other images should be maximized. A very recent and simple method for this is [SimCLR](https://arxiv.org/abs/2006.10029), which is visualized below (figure credit - [Ting Chen et al.](https://simclr.github.io/)).
#
# <center width="100%"><img src="https://github.com/phlippe/uvadlc_notebooks/blob/master/docs/tutorial_notebooks/tutorial17/simclr_contrastive_learning.png?raw=1" width="500px"></center>
#
# The general setup is that we are given a dataset of images without any labels, and want to train a model on this data such that it can quickly adapt to any image recognition task afterward. During each training iteration, we sample a batch of images as usual. For each image, we create two versions by applying data augmentation techniques like cropping, Gaussian noise, blurring, etc. An example of such is shown on the left with the image of the dog. We will go into the details and effects of the chosen augmentation techniques later. On those images, we apply a CNN like ResNet and obtain as output a 1D feature vector on which we apply a small MLP. The output features of the two augmented images are then trained to be close to each other, while all other images in that batch should be as different as possible. This way, the model has to learn to recognize the content of the image that remains unchanged under the data augmentations, such as objects which we usually care about in supervised tasks.
#
# We will now implement this framework ourselves and discuss further details along the way. Let's first start with importing our standard libraries below:

# %%
## Standard libraries
import os
from copy import deepcopy

## Imports for plotting
import matplotlib.pyplot as plt
plt.set_cmap('cividis')
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg', 'pdf') # For export
import matplotlib
matplotlib.rcParams['lines.linewidth'] = 2.0
import seaborn as sns
# sns.set()

## tqdm for loading bars
from tqdm.notebook import tqdm

## NumPy
import numpy as np
## PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import torch.optim as optim

## Torchvision
import torchvision
from torchvision.datasets import STL10
from torchvision import transforms

# Path to the folder where the datasets are/should be downloaded (e.g. CIFAR10)
DATASET_PATH = "./data"
# Path to the folder where the pretrained models are saved
CHECKPOINT_PATH = "./saved_models"
# In this notebook, we use data loaders with heavier computational processing. It is recommended to use as many
# workers as possible in a data loader, which corresponds to the number of CPU cores
NUM_WORKERS = os.cpu_count()

# Ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print("Device:", device)
print("Number of workers:", NUM_WORKERS)
# Out:
# <ipython-input-2-1c690d20540c>:10: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg', 'pdf') # For export
# Device: cuda:0
# Number of workers: 2

# %% [markdown]
# Note that in this Laboratory session some training procedures will require several hours to be run until convergence. For this reason, **you will also have pre-trained models available to download**, so that you will be able to continue the lab even if your model was not fully trained.
#
# Note that those models are slightly larger as normal (~100MB overall) since we use the default ResNet-18 architecture. If you are running this notebook locally, make sure to have sufficient disk space available.

# %%
import urllib.request
from urllib.error import HTTPError
# Github URL where saved models are stored for this tutorial
base_url = "https://raw.githubusercontent.com/phlippe/saved_models/main/tutorial17/"
# Files to download
pretrained_files = ["SimCLR.ckpt", "ResNet.ckpt",
                    "tensorboards/SimCLR/events.out.tfevents.SimCLR",
                    "tensorboards/classification/ResNet/events.out.tfevents.ResNet"]
pretrained_files += [f"LogisticRegression_{size}.ckpt" for size in [10, 20, 50, 100, 200, 500]]
# Create checkpoint path if it doesn't exist yet
os.makedirs(CHECKPOINT_PATH, exist_ok=True)

# For each file, check whether it already exists. If not, try downloading it.
for file_name in pretrained_files:
    file_path = os.path.join(CHECKPOINT_PATH, file_name)
    if "/" in file_name:
        os.makedirs(file_path.rsplit("/",1)[0], exist_ok=True)
    if not os.path.isfile(file_path):
        file_url = base_url + file_name
        print(f"Downloading {file_url}...")
        try:
            urllib.request.urlretrieve(file_url, file_path)
        except HTTPError as e:
            print("Something went wrong. Please try to download the file from the GDrive folder, or contact the author with the full output including the following error:\n", e)
# Out:
# Downloading https://raw.githubusercontent.com/phlippe/saved_models/main/tutorial17/SimCLR.ckpt...
# Downloading https://raw.githubusercontent.com/phlippe/saved_models/main/tutorial17/ResNet.ckpt...
# Downloading https://raw.githubusercontent.com/phlippe/saved_models/main/tutorial17/tensorboards/SimCLR/events.out.tfevents.SimCLR...
# Downloading https://raw.githubusercontent.com/phlippe/saved_models/main/tutorial17/tensorboards/classification/ResNet/events.out.tfevents.ResNet...
# Downloading https://raw.githubusercontent.com/phlippe/saved_models/main/tutorial17/LogisticRegression_10.ckpt...
# Downloading https://raw.githubusercontent.com/phlippe/saved_models/main/tutorial17/LogisticRegression_20.ckpt...
# Downloading https://raw.githubusercontent.com/phlippe/saved_models/main/tutorial17/LogisticRegression_50.ckpt...
# Downloading https://raw.githubusercontent.com/phlippe/saved_models/main/tutorial17/LogisticRegression_100.ckpt...
# Downloading https://raw.githubusercontent.com/phlippe/saved_models/main/tutorial17/LogisticRegression_200.ckpt...
# Downloading https://raw.githubusercontent.com/phlippe/saved_models/main/tutorial17/LogisticRegression_500.ckpt...

# %% [markdown]
# ## SimCLR
#
# We will start our exploration of contrastive learning by discussing the effect of different data augmentation techniques, and how we can implement an efficient data loader for such. Next, we implement the SimCLR architecture, and finally train it on a large, unlabeled dataset.

# %% [markdown]
# ### Data Augmentation for Contrastive Learning
#
# To allow efficient training, we need to prepare the data loading such that we sample two different, random augmentations for each image in the batch. The easiest way to do this is by creating a transformation that, when being called, applies a set of data augmentations to an image twice. This is implemented in the class `ContrastiveTransformations` below:

# %%
class ContrastiveTransformations(object):

    def __init__(self, base_transforms, n_views=2):
        self.base_transforms = base_transforms
        self.n_views = n_views

    def __call__(self, x):
        return [self.base_transforms(x) for i in range(self.n_views)]

# %% [markdown]
# The contrastive learning framework can easily be extended to have more _positive_ examples by sampling more than two augmentations of the same image. However, the most efficient training is usually obtained by using only two.
#
# Next, we can look at the specific augmentations we want to apply. **The choice of the data augmentation to use is the most crucial hyperparameter in SimCLR** since it directly affects how the latent space is structured, and what patterns might be learned from the data. Let's first take a look at some of the most popular data augmentations (figure credit - [Ting Chen and Geoffrey Hinton](https://ai.googleblog.com/2020/04/advancing-self-supervised-and-semi.html)):
#
# <center width="100%"><img src="https://github.com/phlippe/uvadlc_notebooks/blob/master/docs/tutorial_notebooks/tutorial17/simclr_data_augmentations.png?raw=1" width="800px" style="padding-top: 10px; padding-bottom: 10px"></center>
#
# All of them can be used, but it turns out that two augmentations stand out in their importance: **crop-and-resize, and color distortion**. Interestingly, however, they only lead to strong performance if they have been used together as discussed by [Ting Chen et al.](https://arxiv.org/abs/2006.10029) in their SimCLR paper. When performing randomly cropping and resizing, we can distinguish between two situations: (a) cropped image A provides a local view of cropped image B, or (b) cropped images C and D show neighboring views of the same image (figure credit - [Ting Chen and Geoffrey Hinton](https://ai.googleblog.com/2020/04/advancing-self-supervised-and-semi.html)).
#
# <center width="100%"><img src="https://github.com/phlippe/uvadlc_notebooks/blob/master/docs/tutorial_notebooks/tutorial17/crop_views.svg?raw=1" width="400px" style="padding-top: 20px; padding-bottom: 0px"></center>
#
# While situation (a) requires the model to learn some sort of scale invariance to make crops A and B similar in latent space, situation (b) is more challenging since the model needs to recognize an object beyond its limited view. However, without color distortion, there is a loophole that the model can exploit, namely that different crops of the same image usually look very similar in color space. Consider the picture of the dog above. Simply from the color of the fur and the green color tone of the background, you can reason that two patches belong to the same image without actually recognizing the dog in the picture. In this case, the model might end up focusing only on the color histograms of the images, and ignore other more generalizable features. If, however, we distort the colors in the two patches randomly and independently of each other, the model cannot rely on this simple feature anymore. **Hence, by combining random cropping and color distortions, the model can only match two patches by learning generalizable representations.**
#
# Overall, for our experiments, we apply a set of 5 transformations following the original SimCLR setup. Follow the links to the official documentation pages to implement this set of transforms in the below cell.
#
#  - [Random horizontal flip](https://pytorch.org/vision/stable/generated/torchvision.transforms.RandomHorizontalFlip.html), with `p=0.5`;
#  - [Crop-and-resize](https://pytorch.org/vision/main/generated/torchvision.transforms.RandomResizedCrop.html), with `size=96`;
#  - [Color distortion](https://pytorch.org/vision/main/generated/torchvision.transforms.ColorJitter.html), with parameters `0.5, 0.5, 0.5, 0.1` for brightness, contrast, saturation and hue respectively. This transformation must be applied randomly with probability `p=0.8`. To do so, put this transformation inside a [Random Apply](https://pytorch.org/vision/stable/generated/torchvision.transforms.RandomApply.html) transform;
#  - [Random grayscale](https://pytorch.org/vision/main/generated/torchvision.transforms.RandomGrayscale.html), with `p=0.2`;
#  - [Gaussian blur](https://pytorch.org/vision/main/generated/torchvision.transforms.GaussianBlur.html) with `kernel_size=9`.
#
#  In comparison to the [original implementation](https://github.com/google-research/simclr), we reduce the effect of the color jitter slightly (0.5 instead of 0.8 for brightness, contrast, and saturation, and 0.1 instead of 0.2 for hue). In our experiments, this setting obtained better performance and was faster and more stable to train. If, for instance, the brightness scale highly varies in a dataset, the original settings can be more beneficial since the model can't rely on this information anymore to distinguish between images.

# %%
contrast_transforms = transforms.Compose([transforms.RandomHorizontalFlip(p=0.5), # Horizontal flip
                                          transforms.RandomResizedCrop(size=96), # Random crop
                                          transforms.RandomApply([
                                              transforms.ColorJitter(0.5,0.5,0.5,0.1)
                                          ], p=0.8), # Color distorsion
                                          transforms.RandomGrayscale(p=0.2), # Random grayscale
                                          transforms.GaussianBlur(kernel_size=9), # Gaussian blur
                                          transforms.ToTensor(),
                                          transforms.Normalize((0.5,), (0.5,))
                                         ])

# %% [markdown]
# After discussing the data augmentation techniques, we can now focus on the dataset. In this tutorial, we will use the [STL10 dataset](https://cs.stanford.edu/~acoates/stl10/), which, similarly to CIFAR10, contains images of 10 classes: airplane, bird, car, cat, deer, dog, horse, monkey, ship, truck. However, the images have a higher resolution, namely $96\times 96$ pixels, and we are only provided with 500 labeled images per class. Additionally, we have a much larger set of $100,000$ unlabeled images which are similar to the training images but are sampled from a wider range of animals and vehicles. This makes the dataset ideal to showcase the benefits that self-supervised learning offers.
#
# Luckily, the STL10 dataset is provided through torchvision. Keep in mind, however, that since this dataset is relatively large and has a considerably higher resolution than CIFAR10, it requires more disk space (~3GB) and takes a bit of time to download. For our initial discussion of self-supervised learning and SimCLR, we will create two data loaders with our contrastive transformations above: the `unlabeled_data` will be used to train our model via contrastive learning, and `train_data_contrast` will be used as a validation set in contrastive learning.

# %%
unlabeled_data = STL10(root=DATASET_PATH, split='unlabeled', download=True,
                       transform=ContrastiveTransformations(contrast_transforms, n_views=2))
train_data_contrast = STL10(root=DATASET_PATH, split='train', download=True,
                            transform=ContrastiveTransformations(contrast_transforms, n_views=2))
# Out:
# Downloading http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz to ./data/stl10_binary.tar.gz
# 100%|██████████| 2640397119/2640397119 [04:34<00:00, 9616334.71it/s]
# Extracting ./data/stl10_binary.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# Finally, before starting with our implementation of SimCLR, let's look at some example image pairs sampled with our augmentations:

# %%
# Visualize some examples
NUM_IMAGES = 6
imgs = torch.stack([img for idx in range(NUM_IMAGES) for img in unlabeled_data[idx][0]], dim=0)
print(imgs.shape)


img_grid = torchvision.utils.make_grid(imgs, nrow=6, normalize=True, pad_value=0.9)
img_grid = img_grid.permute(1, 2, 0)
plt.figure(figsize=(10,5))
plt.title('Augmented image examples of the STL10 dataset')
plt.imshow(img_grid)
plt.axis('off')
plt.show()
plt.close()
# Out:
# torch.Size([12, 3, 96, 96])

# %% [markdown]
# We see the wide variety of our data augmentation, including randomly cropping, grayscaling, gaussian blur, and color distortion. Thus, it remains a challenging task for the model to match two, independently augmented patches of the same image.

# %% [markdown]
# ### SimCLR implementation
#
# Using the data loader pipeline above, we can now implement SimCLR. At each iteration, we get for every image $x$ two differently augmented versions, which we refer to as $\tilde{x}_i$ and $\tilde{x}_j$. Both of these images are encoded into a one-dimensional feature vector, between which we want to maximize similarity which minimizes it to all other images in the batch. The encoder network is split into two parts: a base encoder network $f(\cdot)$, and a projection head $g(\cdot)$. The base network is usually a deep CNN and is responsible for extracting a representation vector from the augmented data examples. In our experiments, we will use the common ResNet-18 architecture as $f(\cdot)$, and refer to the output as $f(\tilde{x}_i)=h_i$. The projection head $g(\cdot)$ maps the representation $h$ into a space where we apply the contrastive loss, i.e., compare similarities between vectors. It is often chosen to be a small MLP with non-linearities, and for simplicity, we follow the original SimCLR paper setup by defining it as a two-layer MLP with ReLU activation in the hidden layer. Note that in the follow-up paper, [SimCLRv2](https://arxiv.org/abs/2006.10029), the authors mention that larger/wider MLPs can boost the performance considerably. This is why we apply an MLP with four times larger hidden dimensions, but deeper MLPs showed to overfit on the given dataset. The general setup is visualized below (figure credit - [Ting Chen et al.](https://arxiv.org/abs/2006.10029)):
#
# <center width="100%"><img src="https://github.com/phlippe/uvadlc_notebooks/blob/master/docs/tutorial_notebooks/tutorial17/simclr_network_setup.svg?raw=1" width="350px"></center>
#
# After finishing the training with contrastive learning, we will remove the projection head $g(\cdot)$, and use $f(\cdot)$ as a pretrained feature extractor. The representations $z$ that come out of the projection head $g(\cdot)$ have been shown to perform worse than those of the base network $f(\cdot)$ when finetuning the network for a new task. This is likely because the representations $z$ are trained to become invariant to many features like the color that can be important for downstream tasks. Thus, $g(\cdot)$ is only needed for the contrastive learning stage.
#
# We now define the `SimCLR` model in the next cell.
# Our model will be composed of:
#  - Our feature extractor, which will be a ResNet-18. It will return a tensor of dimension `hidden_dim * 4`;
#  - A small final projection head, a small MLP composed of:
#   - The ReLu activation function;
#   - A linear layer with output shape equal to `hidden_dim`
#
#
# Luckily you will not need to write the entire ResNet-18 model from scracth, as it is made available with the `torchvision` package. Use `torchvision.models.resnet18(num_classes=K)` to implement a ResNet-18 architecture with `K` output neurons. Please check the relative documentation for the more implementation details: https://pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html

# %%
class SimCLR(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()

        # Base model f(.), remember to put output shape equal to hidden_dim * 4
        self.convnet = torchvision.models.resnet18(num_classes = 4*hidden_dim)  # Output of last linear layer

        # The MLP for g(.) consists of Linear->ReLU->Linear
        # Note that the resnet18 model provided by torchvision already has a single linear output layer which you can access with convnet.fc
        # We will modify directly that module instead of creating a new one as a new variable
        # NOTE: It's important to follow this structure. This is because PyTorch stores the models' weights under a named dictionary.
        # If you define more modules with other names you will incur in an error when trying to load the weights of the pretrained model
        # later in the notebook.
        self.convnet.fc = nn.Sequential(
            self.convnet.fc,  # Linear(ResNet output, 4*hidden_dim)
            nn.ReLU(inplace=True),
            nn.Linear(4*hidden_dim, hidden_dim)
        )

    def forward(self, x):
        # Encode all images
        feats = self.convnet(x)
        return feats

# %% [markdown]
# ### NT-Xent loss
#
# Now that the architecture is described, let's take a closer look at how we train the model. As mentioned before, we want to maximize the similarity between the representations of the two augmented versions of the same image, i.e., $z_i$ and $z_j$ in the figure above, while minimizing it to all other examples in the batch. SimCLR thereby applies the NT-Xent loss, originally proposed by [Aaron van den Oord et al.](https://arxiv.org/abs/1807.03748) for contrastive learning. In short, the NT-Xent loss compares the similarity of $z_i$ and $z_j$ to the similarity of $z_i$ to any other representation in the batch by performing a softmax over the similarity values. The loss can be formally written as:
#
# $$
# \ell_{i,j}=-\log \frac{\exp(\text{sim}(z_i,z_j)/\tau)}{\sum_{k=1}^{2N}\mathbb{1}_{[k\neq i]}\exp(\text{sim}(z_i,z_k)/\tau)}=-\text{sim}(z_i,z_j)/\tau+\log\left[\sum_{k=1}^{2N}\mathbb{1}_{[k\neq i]}\exp(\text{sim}(z_i,z_k)/\tau)\right]
# $$
#
# The function $\text{sim}$ is a similarity metric, and the hyperparameter $\tau$ is called temperature determining how peaked the distribution is. Since many similarity metrics are bounded, the temperature parameter allows us to balance the influence of many dissimilar image patches versus one similar patch. The similarity metric that is used in SimCLR is cosine similarity, as defined below:
#
# $$
# \text{sim}(z_i,z_j) = \frac{z_i^\top \cdot z_j}{||z_i||\cdot||z_j||}
# $$
#
# The maximum cosine similarity possible is $1$, while the minimum is $-1$. In general, we will see that the features of two different images will converge to a cosine similarity around zero since the minimum, $-1$, would require $z_i$ and $z_j$ to be in the exact opposite direction in all feature dimensions, which does not allow for great flexibility.

# %% [markdown]
# Alternatively to performing the validation on the contrastive learning loss as well, we could also take a simple, small downstream task, and track the performance of the base network $f(\cdot)$ on that. However, in this tutorial, we will restrict ourselves to the STL10 dataset where we use the task of image classification on STL10 as our test task.

# %%
def NT_Xent_loss(features_batch, temperature, mode='train'):
    """
    Takes in input a features_batch tensor of shape (BatchSize * 2, feature_dim), the temperature parameter,
    and computes the NT_Xent_loss
    """

    # Calculate cosine similarity between all possible couples of examples in the features_batch tensor
    # Result must be a (BatchSize*2, BatchSize*2) tensor
    # Hints:
    # 1) Check the documentation https://pytorch.org/docs/stable/generated/torch.nn.functional.cosine_similarity.html
    # 2) Use broadcasting!

    cos_sim = F.cosine_similarity(features_batch[:,None,:],features_batch[None,:,:],dim=-1)

    # Mask out cosine similarity to itself
    self_mask = torch.eye(cos_sim.shape[0], dtype=torch.bool, device=cos_sim.device)
    cos_sim.masked_fill_(self_mask, -9e15)

    # Find the positive example, we know that it is batch_size//2 away from the original example
    pos_mask = self_mask.roll(shifts=cos_sim.shape[0]//2, dims=0)

    # NT_Xent loss
    cos_sim = cos_sim / temperature

    nll = -cos_sim[pos_mask] + torch.logsumexp(cos_sim, dim=-1)
    nll = nll.mean()

    # Get ranking position of positive example
    comb_sim = torch.cat([cos_sim[pos_mask][:,None],  # First position positive example
                            cos_sim.masked_fill(pos_mask, -9e15)],
                            dim=-1)
    sim_argsort = comb_sim.argsort(dim=-1, descending=True).argmin(dim=-1)

    acc_top1 = (sim_argsort == 0).float().mean()
    acc_top5 = (sim_argsort < 5).float().mean()

    return nll, acc_top1, acc_top5

# %% [markdown]
# ### Training
#
# Now that we have implemented SimCLR and the data loading pipeline, we are ready to train the model.
#
# Other than tracking the loss, we also track the top-5 accuracy metric, which describes how often the correct image patch is within the top-5 most similar examples in the batch. This is usually less noisy than the top-1 metric, making it a better metric to use for monitoring potential overfitting.

# %%
def train(model, device, train_loader, optimizer, lr_scheduler, epoch, loss_temperature, maxit=10):
    train_losses = []
    train_top5_accs = []

    model.train()
    model.to(device)
    for i, batch in enumerate(train_loader):
        imgs, _ = batch

        # Concatenate the two images along the batch dimension, so we get a tensor of shape (BatchDim * 2, 3, 96, 96)
        # Also remember to put the images on the GPU
        cat_imgs = torch.cat(imgs, dim=0).to(device)

        # Compute the features
        features = model(cat_imgs)

        # Compute the loss together with the accuracy metrics, and store them in the lists above
        nce_loss, acc_top1, acc_top5 = NT_Xent_loss(features, loss_temperature)
        train_losses.append(nce_loss.item())
        train_top5_accs.append(acc_top5.item())

        # Backpropagate the loss and perform the optimization step
        optimizer.zero_grad()
        nce_loss.backward()
        optimizer.step()

        print(f"Train Epoch: {epoch}, Iteration: {i}/{len(train_loader)},  \tLoss: {nce_loss.item():.6f}, \tTop1_Acc: {acc_top1.item():.6f}, \tTop5_Acc: {acc_top5.item():.6f}")

        if i >= maxit:
            return np.mean(train_losses), np.mean(train_top5_accs)
            break

    lr_scheduler.step()
    return np.mean(train_losses), np.mean(train_top5_accs)

@torch.no_grad()
def valid(model, device, val_loader, epoch, loss_temperature, maxit=10):
    model.eval()
    val_losses = []
    val_top5_accs = []
    for i, batch in enumerate(val_loader):
        imgs, _ = batch

        # Concatenate the images
        imgs = torch.cat(imgs, dim=0).to(device)

        # Compute the features
        features = model(imgs)

        # Compute loss and accuracies, and store them
        nce_loss, acc_top1, acc_top5 = NT_Xent_loss(features, loss_temperature)
        train_losses.append(nce_loss.item())
        train_top5_accs.append(acc_top5.item())

        print(f"Valid Epoch: {epoch}, Iteration: {i}/{len(val_loader)},  \tLoss: {nce_loss.item():.6f}, \tTop1_Acc: {acc_top1.item():.6f}, \tTop5_Acc: {acc_top5.item():.6f}")
        if i >= maxit:
          return np.mean(val_losses), np.mean(val_top5_accs)
          break

    return np.mean(val_losses), np.mean(val_top5_accs)

# %% [markdown]
# Now that we have implemented the functions for the training and validation iterations, we are ready to write the full training loop.
#
#
# A common observation in contrastive learning is that **the larger the batch size, the better the models perform**. A larger batch size allows us to compare each image to more negative examples, leading to overall smoother loss gradients. However, in our case, we experienced that a batch size of 256 was sufficient to get good results.
#
# **IMPORTANT NOTE:** Training the SimCLR to convergence would require a very long training session. For the sake of this laboratory, we will just run a much reduced training procedure with 10 epochs, where for each epoch we will train the model on only `maxit` batches. (Setting `maxit=10` this cell will take around 10 minutes to run, but feel free to set `maxit` to a bigger number if you can afford spending more time for the training procedure, or if you have access to more powerful computational resources).
#
# For the next sections of the Laboratory you will be able to load the weights of a fully trained SimCLR model, to see its actual performances.

# %%
# Define training hyperparameters
batch_size=256
hidden_dim=128
temperature=0.07
weight_decay=1e-4
max_epochs=500
lr=2e-4

epochs = 10
maxit = 10

# Define Loaders
train_loader = data.DataLoader(unlabeled_data, batch_size=batch_size, shuffle=True,
                                drop_last=True, pin_memory=True, num_workers=NUM_WORKERS)
val_loader = data.DataLoader(train_data_contrast, batch_size=batch_size, shuffle=False,
                                drop_last=False, pin_memory=True, num_workers=NUM_WORKERS)
# Define SimCLR Model
simclr_model = SimCLR(hidden_dim)

# Define Optimizer and Learning rate Scheduler
optimizer = optim.AdamW(simclr_model.parameters(), lr=lr, weight_decay=weight_decay)
lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max = max_epochs, eta_min=lr/50)

# Training Loop
train_losses = []
val_losses = []
train_top5_accs = []
val_top5_accs = []

for epoch in range(epochs):
    # Training iterations and update lists
    train_loss, train_top5_acc = train(simclr_model, device, train_loader, optimizer, lr_scheduler, epoch, temperature, maxit)
    train_losses.append(train_loss)
    train_top5_accs.append(train_top5_acc)
    print()

    # Validation iterations
    val_loss, val_top5_acc = valid(simclr_model, device, val_loader, epoch, temperature, maxit)
    val_losses.append(val_loss)
    val_top5_accs.append(val_top5_acc)
    print()

# Save the model
torch.save(simclr_model.state_dict(), os.path.join(CHECKPOINT_PATH, 'My_SimCLR.ckpt'))
# Out:
# Train Epoch: 0, Iteration: 0/390,  	Loss: 6.229095, 	Top1_Acc: 0.005859, 	Top5_Acc: 0.039062
# Train Epoch: 0, Iteration: 1/390,  	Loss: 6.341122, 	Top1_Acc: 0.011719, 	Top5_Acc: 0.041016
# Train Epoch: 0, Iteration: 2/390,  	Loss: 6.154682, 	Top1_Acc: 0.023438, 	Top5_Acc: 0.048828
# Train Epoch: 0, Iteration: 3/390,  	Loss: 6.097002, 	Top1_Acc: 0.007812, 	Top5_Acc: 0.048828
# Train Epoch: 0, Iteration: 4/390,  	Loss: 6.095674, 	Top1_Acc: 0.015625, 	Top5_Acc: 0.050781
# Train Epoch: 0, Iteration: 5/390,  	Loss: 6.149941, 	Top1_Acc: 0.003906, 	Top5_Acc: 0.039062
# Train Epoch: 0, Iteration: 6/390,  	Loss: 6.031608, 	Top1_Acc: 0.029297, 	Top5_Acc: 0.068359
# Train Epoch: 0, Iteration: 7/390,  	Loss: 6.013870, 	Top1_Acc: 0.019531, 	Top5_Acc: 0.072266
# Train Epoch: 0, Iteration: 8/390,  	Loss: 5.926539, 	Top1_Acc: 0.019531, 	Top5_Acc: 0.068359
# Train Epoch: 0, Iteration: 9/390,  	Loss: 5.946448, 	Top1_Acc: 0.013672, 	Top5_Acc: 0.060547
# Train Epoch: 0, Iteration: 10/390,  	Loss: 5.881850, 	Top1_Acc: 0.025391, 	Top5_Acc: 0.068359
#
# Valid Epoch: 0, Iteration: 0/20,  	Loss: 6.045808, 	Top1_Acc: 0.015625, 	Top5_Acc: 0.070312
# Valid Epoch: 0, Iteration: 1/20,  	Loss: 6.068717, 	Top1_Acc: 0.027344, 	Top5_Acc: 0.062500
# Valid Epoch: 0, Iteration: 2/20,  	Loss: 6.072078, 	Top1_Acc: 0.031250, 	Top5_Acc: 0.074219
# Valid Epoch: 0, Iteration: 3/20,  	Loss: 6.030115, 	Top1_Acc: 0.015625, 	Top5_Acc: 0.058594
# Valid Epoch: 0, Iteration: 4/20,  	Loss: 6.046877, 	Top1_Acc: 0.027344, 	Top5_Acc: 0.058594
# Valid Epoch: 0, Iteration: 5/20,  	Loss: 6.063017, 	Top1_Acc: 0.021484, 	Top5_Acc: 0.064453
# Valid Epoch: 0, Iteration: 6/20,  	Loss: 6.062121, 	Top1_Acc: 0.037109, 	Top5_Acc: 0.095703
# Valid Epoch: 0, Iteration: 7/20,  	Loss: 6.028349, 	Top1_Acc: 0.029297, 	Top5_Acc: 0.064453
# Valid Epoch: 0, Iteration: 8/20,  	Loss: 6.121660, 	Top1_Acc: 0.031250, 	Top5_Acc: 0.080078
# Valid Epoch: 0, Iteration: 9/20,  	Loss: 6.055254, 	Top1_Acc: 0.029297, 	Top5_Acc: 0.068359
# Valid Epoch: 0, Iteration: 10/20,  	Loss: 6.042625, 	Top1_Acc: 0.037109, 	Top5_Acc: 0.068359
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Train Epoch: 1, Iteration: 0/390,  	Loss: 6.001757, 	Top1_Acc: 0.015625, 	Top5_Acc: 0.070312
# Train Epoch: 1, Iteration: 1/390,  	Loss: 5.786363, 	Top1_Acc: 0.029297, 	Top5_Acc: 0.103516
# Train Epoch: 1, Iteration: 2/390,  	Loss: 5.862997, 	Top1_Acc: 0.019531, 	Top5_Acc: 0.066406
# Train Epoch: 1, Iteration: 3/390,  	Loss: 5.751883, 	Top1_Acc: 0.031250, 	Top5_Acc: 0.085938
# Train Epoch: 1, Iteration: 4/390,  	Loss: 5.717562, 	Top1_Acc: 0.025391, 	Top5_Acc: 0.097656
# Train Epoch: 1, Iteration: 5/390,  	Loss: 5.854679, 	Top1_Acc: 0.037109, 	Top5_Acc: 0.113281
# Train Epoch: 1, Iteration: 6/390,  	Loss: 5.625505, 	Top1_Acc: 0.039062, 	Top5_Acc: 0.099609
# Train Epoch: 1, Iteration: 7/390,  	Loss: 5.835495, 	Top1_Acc: 0.027344, 	Top5_Acc: 0.091797
# Train Epoch: 1, Iteration: 8/390,  	Loss: 5.600257, 	Top1_Acc: 0.044922, 	Top5_Acc: 0.123047
# Train Epoch: 1, Iteration: 9/390,  	Loss: 5.620471, 	Top1_Acc: 0.044922, 	Top5_Acc: 0.134766
# Train Epoch: 1, Iteration: 10/390,  	Loss: 5.707184, 	Top1_Acc: 0.023438, 	Top5_Acc: 0.066406
#
# Valid Epoch: 1, Iteration: 0/20,  	Loss: 5.821465, 	Top1_Acc: 0.046875, 	Top5_Acc: 0.109375
# Valid Epoch: 1, Iteration: 1/20,  	Loss: 5.862837, 	Top1_Acc: 0.031250, 	Top5_Acc: 0.095703
# Valid Epoch: 1, Iteration: 2/20,  	Loss: 5.923065, 	Top1_Acc: 0.013672, 	Top5_Acc: 0.054688
# Valid Epoch: 1, Iteration: 3/20,  	Loss: 5.873805, 	Top1_Acc: 0.025391, 	Top5_Acc: 0.087891
# Valid Epoch: 1, Iteration: 4/20,  	Loss: 5.929301, 	Top1_Acc: 0.044922, 	Top5_Acc: 0.093750
# Valid Epoch: 1, Iteration: 5/20,  	Loss: 5.922231, 	Top1_Acc: 0.025391, 	Top5_Acc: 0.078125
# Valid Epoch: 1, Iteration: 6/20,  	Loss: 5.863247, 	Top1_Acc: 0.025391, 	Top5_Acc: 0.091797
# Valid Epoch: 1, Iteration: 7/20,  	Loss: 5.832314, 	Top1_Acc: 0.035156, 	Top5_Acc: 0.085938
# Valid Epoch: 1, Iteration: 8/20,  	Loss: 5.865362, 	Top1_Acc: 0.021484, 	Top5_Acc: 0.072266
# Valid Epoch: 1, Iteration: 9/20,  	Loss: 5.871652, 	Top1_Acc: 0.023438, 	Top5_Acc: 0.074219
# Valid Epoch: 1, Iteration: 10/20,  	Loss: 5.853327, 	Top1_Acc: 0.033203, 	Top5_Acc: 0.087891
#
# Train Epoch: 2, Iteration: 0/390,  	Loss: 5.673100, 	Top1_Acc: 0.052734, 	Top5_Acc: 0.117188
# Train Epoch: 2, Iteration: 1/390,  	Loss: 5.561122, 	Top1_Acc: 0.054688, 	Top5_Acc: 0.119141
# Train Epoch: 2, Iteration: 2/390,  	Loss: 5.475163, 	Top1_Acc: 0.052734, 	Top5_Acc: 0.136719
# Train Epoch: 2, Iteration: 3/390,  	Loss: 5.469218, 	Top1_Acc: 0.048828, 	Top5_Acc: 0.148438
# Train Epoch: 2, Iteration: 4/390,  	Loss: 5.499894, 	Top1_Acc: 0.044922, 	Top5_Acc: 0.167969
# Train Epoch: 2, Iteration: 5/390,  	Loss: 5.543458, 	Top1_Acc: 0.048828, 	Top5_Acc: 0.136719
# Train Epoch: 2, Iteration: 6/390,  	Loss: 5.409714, 	Top1_Acc: 0.044922, 	Top5_Acc: 0.144531
# Train Epoch: 2, Iteration: 7/390,  	Loss: 5.412478, 	Top1_Acc: 0.068359, 	Top5_Acc: 0.173828
# Train Epoch: 2, Iteration: 8/390,  	Loss: 5.447343, 	Top1_Acc: 0.074219, 	Top5_Acc: 0.173828
# Train Epoch: 2, Iteration: 9/390,  	Loss: 5.450784, 	Top1_Acc: 0.025391, 	Top5_Acc: 0.113281
# Train Epoch: 2, Iteration: 10/390,  	Loss: 5.355361, 	Top1_Acc: 0.058594, 	Top5_Acc: 0.154297
#
# Valid Epoch: 2, Iteration: 0/20,  	Loss: 5.602342, 	Top1_Acc: 0.042969, 	Top5_Acc: 0.132812
# Valid Epoch: 2, Iteration: 1/20,  	Loss: 5.631753, 	Top1_Acc: 0.037109, 	Top5_Acc: 0.128906
# Valid Epoch: 2, Iteration: 2/20,  	Loss: 5.579915, 	Top1_Acc: 0.037109, 	Top5_Acc: 0.128906
# Valid Epoch: 2, Iteration: 3/20,  	Loss: 5.528403, 	Top1_Acc: 0.037109, 	Top5_Acc: 0.146484
# Valid Epoch: 2, Iteration: 4/20,  	Loss: 5.674904, 	Top1_Acc: 0.042969, 	Top5_Acc: 0.126953
# Valid Epoch: 2, Iteration: 5/20,  	Loss: 5.715183, 	Top1_Acc: 0.056641, 	Top5_Acc: 0.107422
# Valid Epoch: 2, Iteration: 6/20,  	Loss: 5.675967, 	Top1_Acc: 0.025391, 	Top5_Acc: 0.113281
# Valid Epoch: 2, Iteration: 7/20,  	Loss: 5.715308, 	Top1_Acc: 0.041016, 	Top5_Acc: 0.144531
# Valid Epoch: 2, Iteration: 8/20,  	Loss: 5.671931, 	Top1_Acc: 0.064453, 	Top5_Acc: 0.123047
# Valid Epoch: 2, Iteration: 9/20,  	Loss: 5.704003, 	Top1_Acc: 0.056641, 	Top5_Acc: 0.121094
# Valid Epoch: 2, Iteration: 10/20,  	Loss: 5.636697, 	Top1_Acc: 0.042969, 	Top5_Acc: 0.117188
#
# Train Epoch: 3, Iteration: 0/390,  	Loss: 5.601971, 	Top1_Acc: 0.037109, 	Top5_Acc: 0.115234
# Train Epoch: 3, Iteration: 1/390,  	Loss: 5.486692, 	Top1_Acc: 0.044922, 	Top5_Acc: 0.134766
# Train Epoch: 3, Iteration: 2/390,  	Loss: 5.441832, 	Top1_Acc: 0.052734, 	Top5_Acc: 0.138672
# Train Epoch: 3, Iteration: 3/390,  	Loss: 5.197088, 	Top1_Acc: 0.062500, 	Top5_Acc: 0.210938
# Train Epoch: 3, Iteration: 4/390,  	Loss: 5.380569, 	Top1_Acc: 0.052734, 	Top5_Acc: 0.156250
# Train Epoch: 3, Iteration: 5/390,  	Loss: 5.441265, 	Top1_Acc: 0.042969, 	Top5_Acc: 0.158203
# Train Epoch: 3, Iteration: 6/390,  	Loss: 5.354132, 	Top1_Acc: 0.050781, 	Top5_Acc: 0.150391
# Train Epoch: 3, Iteration: 7/390,  	Loss: 5.235181, 	Top1_Acc: 0.074219, 	Top5_Acc: 0.183594
# Train Epoch: 3, Iteration: 8/390,  	Loss: 5.327630, 	Top1_Acc: 0.078125, 	Top5_Acc: 0.169922
# Train Epoch: 3, Iteration: 9/390,  	Loss: 5.418303, 	Top1_Acc: 0.056641, 	Top5_Acc: 0.134766
# Train Epoch: 3, Iteration: 10/390,  	Loss: 5.236800, 	Top1_Acc: 0.074219, 	Top5_Acc: 0.210938
#
# Valid Epoch: 3, Iteration: 0/20,  	Loss: 5.197304, 	Top1_Acc: 0.060547, 	Top5_Acc: 0.179688
# Valid Epoch: 3, Iteration: 1/20,  	Loss: 5.277179, 	Top1_Acc: 0.076172, 	Top5_Acc: 0.154297
# Valid Epoch: 3, Iteration: 2/20,  	Loss: 5.400284, 	Top1_Acc: 0.054688, 	Top5_Acc: 0.171875
# Valid Epoch: 3, Iteration: 3/20,  	Loss: 5.416204, 	Top1_Acc: 0.062500, 	Top5_Acc: 0.171875
# Valid Epoch: 3, Iteration: 4/20,  	Loss: 5.406801, 	Top1_Acc: 0.042969, 	Top5_Acc: 0.128906
# Valid Epoch: 3, Iteration: 5/20,  	Loss: 5.358869, 	Top1_Acc: 0.082031, 	Top5_Acc: 0.171875
# Valid Epoch: 3, Iteration: 6/20,  	Loss: 5.423526, 	Top1_Acc: 0.044922, 	Top5_Acc: 0.152344
# Valid Epoch: 3, Iteration: 7/20,  	Loss: 5.500292, 	Top1_Acc: 0.064453, 	Top5_Acc: 0.162109
# Valid Epoch: 3, Iteration: 8/20,  	Loss: 5.497634, 	Top1_Acc: 0.056641, 	Top5_Acc: 0.152344
# Valid Epoch: 3, Iteration: 9/20,  	Loss: 5.327612, 	Top1_Acc: 0.048828, 	Top5_Acc: 0.144531
# Valid Epoch: 3, Iteration: 10/20,  	Loss: 5.350643, 	Top1_Acc: 0.048828, 	Top5_Acc: 0.128906
#
# Train Epoch: 4, Iteration: 0/390,  	Loss: 5.325559, 	Top1_Acc: 0.058594, 	Top5_Acc: 0.162109
# Train Epoch: 4, Iteration: 1/390,  	Loss: 5.295949, 	Top1_Acc: 0.058594, 	Top5_Acc: 0.164062
# Train Epoch: 4, Iteration: 2/390,  	Loss: 5.204547, 	Top1_Acc: 0.087891, 	Top5_Acc: 0.201172
# Train Epoch: 4, Iteration: 3/390,  	Loss: 5.350078, 	Top1_Acc: 0.058594, 	Top5_Acc: 0.169922
# Train Epoch: 4, Iteration: 4/390,  	Loss: 5.217614, 	Top1_Acc: 0.056641, 	Top5_Acc: 0.164062
# Train Epoch: 4, Iteration: 5/390,  	Loss: 5.321922, 	Top1_Acc: 0.083984, 	Top5_Acc: 0.179688
# Train Epoch: 4, Iteration: 6/390,  	Loss: 5.247790, 	Top1_Acc: 0.058594, 	Top5_Acc: 0.185547
# Train Epoch: 4, Iteration: 7/390,  	Loss: 5.357018, 	Top1_Acc: 0.058594, 	Top5_Acc: 0.162109
# Train Epoch: 4, Iteration: 8/390,  	Loss: 5.280229, 	Top1_Acc: 0.082031, 	Top5_Acc: 0.203125
# Train Epoch: 4, Iteration: 9/390,  	Loss: 5.206245, 	Top1_Acc: 0.089844, 	Top5_Acc: 0.201172
# Train Epoch: 4, Iteration: 10/390,  	Loss: 5.061114, 	Top1_Acc: 0.087891, 	Top5_Acc: 0.214844
#
# Valid Epoch: 4, Iteration: 0/20,  	Loss: 5.220674, 	Top1_Acc: 0.085938, 	Top5_Acc: 0.205078
# Valid Epoch: 4, Iteration: 1/20,  	Loss: 5.343120, 	Top1_Acc: 0.070312, 	Top5_Acc: 0.152344
# Valid Epoch: 4, Iteration: 2/20,  	Loss: 5.254647, 	Top1_Acc: 0.095703, 	Top5_Acc: 0.187500
# Valid Epoch: 4, Iteration: 3/20,  	Loss: 5.288380, 	Top1_Acc: 0.080078, 	Top5_Acc: 0.167969
# Valid Epoch: 4, Iteration: 4/20,  	Loss: 5.405234, 	Top1_Acc: 0.089844, 	Top5_Acc: 0.195312
# Valid Epoch: 4, Iteration: 5/20,  	Loss: 5.367804, 	Top1_Acc: 0.060547, 	Top5_Acc: 0.181641
# Valid Epoch: 4, Iteration: 6/20,  	Loss: 5.224225, 	Top1_Acc: 0.058594, 	Top5_Acc: 0.173828
# Valid Epoch: 4, Iteration: 7/20,  	Loss: 5.325735, 	Top1_Acc: 0.044922, 	Top5_Acc: 0.179688
# Valid Epoch: 4, Iteration: 8/20,  	Loss: 5.276423, 	Top1_Acc: 0.087891, 	Top5_Acc: 0.214844
# Valid Epoch: 4, Iteration: 9/20,  	Loss: 5.193047, 	Top1_Acc: 0.076172, 	Top5_Acc: 0.199219
# Valid Epoch: 4, Iteration: 10/20,  	Loss: 5.321228, 	Top1_Acc: 0.060547, 	Top5_Acc: 0.171875
#
# Train Epoch: 5, Iteration: 0/390,  	Loss: 5.260821, 	Top1_Acc: 0.066406, 	Top5_Acc: 0.207031
# Train Epoch: 5, Iteration: 1/390,  	Loss: 5.202245, 	Top1_Acc: 0.089844, 	Top5_Acc: 0.236328
# Train Epoch: 5, Iteration: 2/390,  	Loss: 5.213115, 	Top1_Acc: 0.076172, 	Top5_Acc: 0.201172
# Train Epoch: 5, Iteration: 3/390,  	Loss: 5.138901, 	Top1_Acc: 0.095703, 	Top5_Acc: 0.205078
# Train Epoch: 5, Iteration: 4/390,  	Loss: 4.976685, 	Top1_Acc: 0.097656, 	Top5_Acc: 0.226562
# Train Epoch: 5, Iteration: 5/390,  	Loss: 5.178756, 	Top1_Acc: 0.066406, 	Top5_Acc: 0.187500
# Train Epoch: 5, Iteration: 6/390,  	Loss: 5.098055, 	Top1_Acc: 0.076172, 	Top5_Acc: 0.228516
# Train Epoch: 5, Iteration: 7/390,  	Loss: 5.122896, 	Top1_Acc: 0.111328, 	Top5_Acc: 0.253906
# Train Epoch: 5, Iteration: 8/390,  	Loss: 4.868984, 	Top1_Acc: 0.126953, 	Top5_Acc: 0.283203
# Train Epoch: 5, Iteration: 9/390,  	Loss: 5.073998, 	Top1_Acc: 0.076172, 	Top5_Acc: 0.251953
# Train Epoch: 5, Iteration: 10/390,  	Loss: 5.168589, 	Top1_Acc: 0.091797, 	Top5_Acc: 0.201172
#
# Valid Epoch: 5, Iteration: 0/20,  	Loss: 4.978323, 	Top1_Acc: 0.109375, 	Top5_Acc: 0.257812
# Valid Epoch: 5, Iteration: 1/20,  	Loss: 5.071484, 	Top1_Acc: 0.089844, 	Top5_Acc: 0.222656
# Valid Epoch: 5, Iteration: 2/20,  	Loss: 5.067727, 	Top1_Acc: 0.117188, 	Top5_Acc: 0.257812
# Valid Epoch: 5, Iteration: 3/20,  	Loss: 5.077333, 	Top1_Acc: 0.072266, 	Top5_Acc: 0.226562
# Valid Epoch: 5, Iteration: 4/20,  	Loss: 5.081194, 	Top1_Acc: 0.111328, 	Top5_Acc: 0.246094
# Valid Epoch: 5, Iteration: 5/20,  	Loss: 5.143529, 	Top1_Acc: 0.089844, 	Top5_Acc: 0.212891
# Valid Epoch: 5, Iteration: 6/20,  	Loss: 5.186981, 	Top1_Acc: 0.087891, 	Top5_Acc: 0.214844
# Valid Epoch: 5, Iteration: 7/20,  	Loss: 5.054669, 	Top1_Acc: 0.097656, 	Top5_Acc: 0.228516
# Valid Epoch: 5, Iteration: 8/20,  	Loss: 5.178767, 	Top1_Acc: 0.119141, 	Top5_Acc: 0.226562
# Valid Epoch: 5, Iteration: 9/20,  	Loss: 5.070636, 	Top1_Acc: 0.107422, 	Top5_Acc: 0.253906
# Valid Epoch: 5, Iteration: 10/20,  	Loss: 4.979085, 	Top1_Acc: 0.111328, 	Top5_Acc: 0.224609
#
# Train Epoch: 6, Iteration: 0/390,  	Loss: 5.018920, 	Top1_Acc: 0.093750, 	Top5_Acc: 0.214844
# Train Epoch: 6, Iteration: 1/390,  	Loss: 4.855883, 	Top1_Acc: 0.097656, 	Top5_Acc: 0.251953
# Train Epoch: 6, Iteration: 2/390,  	Loss: 5.003110, 	Top1_Acc: 0.125000, 	Top5_Acc: 0.255859
# Train Epoch: 6, Iteration: 3/390,  	Loss: 4.979743, 	Top1_Acc: 0.097656, 	Top5_Acc: 0.246094
# Train Epoch: 6, Iteration: 4/390,  	Loss: 5.136448, 	Top1_Acc: 0.085938, 	Top5_Acc: 0.224609
# Train Epoch: 6, Iteration: 5/390,  	Loss: 4.850407, 	Top1_Acc: 0.146484, 	Top5_Acc: 0.277344
# Train Epoch: 6, Iteration: 6/390,  	Loss: 4.858271, 	Top1_Acc: 0.107422, 	Top5_Acc: 0.257812
# Train Epoch: 6, Iteration: 7/390,  	Loss: 5.065284, 	Top1_Acc: 0.093750, 	Top5_Acc: 0.244141
# Train Epoch: 6, Iteration: 8/390,  	Loss: 4.860344, 	Top1_Acc: 0.130859, 	Top5_Acc: 0.289062
# Train Epoch: 6, Iteration: 9/390,  	Loss: 4.836748, 	Top1_Acc: 0.132812, 	Top5_Acc: 0.257812
# Train Epoch: 6, Iteration: 10/390,  	Loss: 4.824529, 	Top1_Acc: 0.123047, 	Top5_Acc: 0.281250
#
# Valid Epoch: 6, Iteration: 0/20,  	Loss: 5.116362, 	Top1_Acc: 0.119141, 	Top5_Acc: 0.242188
# Valid Epoch: 6, Iteration: 1/20,  	Loss: 5.088408, 	Top1_Acc: 0.119141, 	Top5_Acc: 0.285156
# Valid Epoch: 6, Iteration: 2/20,  	Loss: 5.022631, 	Top1_Acc: 0.128906, 	Top5_Acc: 0.259766
# Valid Epoch: 6, Iteration: 3/20,  	Loss: 5.232100, 	Top1_Acc: 0.091797, 	Top5_Acc: 0.207031
# Valid Epoch: 6, Iteration: 4/20,  	Loss: 5.076089, 	Top1_Acc: 0.119141, 	Top5_Acc: 0.259766
# Valid Epoch: 6, Iteration: 5/20,  	Loss: 5.252120, 	Top1_Acc: 0.109375, 	Top5_Acc: 0.246094
# Valid Epoch: 6, Iteration: 6/20,  	Loss: 5.318497, 	Top1_Acc: 0.103516, 	Top5_Acc: 0.250000
# Valid Epoch: 6, Iteration: 7/20,  	Loss: 5.077018, 	Top1_Acc: 0.115234, 	Top5_Acc: 0.265625
# Valid Epoch: 6, Iteration: 8/20,  	Loss: 4.972513, 	Top1_Acc: 0.125000, 	Top5_Acc: 0.283203
# Valid Epoch: 6, Iteration: 9/20,  	Loss: 5.172948, 	Top1_Acc: 0.085938, 	Top5_Acc: 0.205078
# Valid Epoch: 6, Iteration: 10/20,  	Loss: 5.143592, 	Top1_Acc: 0.089844, 	Top5_Acc: 0.234375
#
# Train Epoch: 7, Iteration: 0/390,  	Loss: 5.017721, 	Top1_Acc: 0.140625, 	Top5_Acc: 0.269531
# Train Epoch: 7, Iteration: 1/390,  	Loss: 4.926767, 	Top1_Acc: 0.115234, 	Top5_Acc: 0.228516
# Train Epoch: 7, Iteration: 2/390,  	Loss: 4.922426, 	Top1_Acc: 0.089844, 	Top5_Acc: 0.238281
# Train Epoch: 7, Iteration: 3/390,  	Loss: 4.984929, 	Top1_Acc: 0.097656, 	Top5_Acc: 0.250000
# Train Epoch: 7, Iteration: 4/390,  	Loss: 4.954204, 	Top1_Acc: 0.105469, 	Top5_Acc: 0.248047
# Train Epoch: 7, Iteration: 5/390,  	Loss: 4.861024, 	Top1_Acc: 0.113281, 	Top5_Acc: 0.267578
# Train Epoch: 7, Iteration: 6/390,  	Loss: 4.828651, 	Top1_Acc: 0.111328, 	Top5_Acc: 0.271484
# Train Epoch: 7, Iteration: 7/390,  	Loss: 4.676745, 	Top1_Acc: 0.121094, 	Top5_Acc: 0.296875
# Train Epoch: 7, Iteration: 8/390,  	Loss: 5.041761, 	Top1_Acc: 0.136719, 	Top5_Acc: 0.232422
# Train Epoch: 7, Iteration: 9/390,  	Loss: 4.894071, 	Top1_Acc: 0.130859, 	Top5_Acc: 0.265625
# Train Epoch: 7, Iteration: 10/390,  	Loss: 4.953562, 	Top1_Acc: 0.107422, 	Top5_Acc: 0.236328
#
# Valid Epoch: 7, Iteration: 0/20,  	Loss: 4.925748, 	Top1_Acc: 0.125000, 	Top5_Acc: 0.267578
# Valid Epoch: 7, Iteration: 1/20,  	Loss: 4.936337, 	Top1_Acc: 0.109375, 	Top5_Acc: 0.275391
# Valid Epoch: 7, Iteration: 2/20,  	Loss: 4.864113, 	Top1_Acc: 0.117188, 	Top5_Acc: 0.277344
# Valid Epoch: 7, Iteration: 3/20,  	Loss: 4.723755, 	Top1_Acc: 0.140625, 	Top5_Acc: 0.267578
# Valid Epoch: 7, Iteration: 4/20,  	Loss: 4.956370, 	Top1_Acc: 0.097656, 	Top5_Acc: 0.242188
# Valid Epoch: 7, Iteration: 5/20,  	Loss: 5.012085, 	Top1_Acc: 0.113281, 	Top5_Acc: 0.238281
# Valid Epoch: 7, Iteration: 6/20,  	Loss: 4.959426, 	Top1_Acc: 0.105469, 	Top5_Acc: 0.248047
# Valid Epoch: 7, Iteration: 7/20,  	Loss: 4.779558, 	Top1_Acc: 0.126953, 	Top5_Acc: 0.279297
# Valid Epoch: 7, Iteration: 8/20,  	Loss: 4.783746, 	Top1_Acc: 0.115234, 	Top5_Acc: 0.259766
# Valid Epoch: 7, Iteration: 9/20,  	Loss: 4.895698, 	Top1_Acc: 0.111328, 	Top5_Acc: 0.283203
# Valid Epoch: 7, Iteration: 10/20,  	Loss: 4.672847, 	Top1_Acc: 0.119141, 	Top5_Acc: 0.298828
#
# Train Epoch: 8, Iteration: 0/390,  	Loss: 4.836267, 	Top1_Acc: 0.113281, 	Top5_Acc: 0.255859
# Train Epoch: 8, Iteration: 1/390,  	Loss: 4.835521, 	Top1_Acc: 0.111328, 	Top5_Acc: 0.263672
# Train Epoch: 8, Iteration: 2/390,  	Loss: 4.952125, 	Top1_Acc: 0.089844, 	Top5_Acc: 0.232422
# Train Epoch: 8, Iteration: 3/390,  	Loss: 4.721669, 	Top1_Acc: 0.167969, 	Top5_Acc: 0.328125
# Train Epoch: 8, Iteration: 4/390,  	Loss: 4.733975, 	Top1_Acc: 0.150391, 	Top5_Acc: 0.320312
# Train Epoch: 8, Iteration: 5/390,  	Loss: 4.799719, 	Top1_Acc: 0.138672, 	Top5_Acc: 0.326172
# Train Epoch: 8, Iteration: 6/390,  	Loss: 4.962744, 	Top1_Acc: 0.095703, 	Top5_Acc: 0.212891
# Train Epoch: 8, Iteration: 7/390,  	Loss: 4.738700, 	Top1_Acc: 0.099609, 	Top5_Acc: 0.259766
# Train Epoch: 8, Iteration: 8/390,  	Loss: 4.677036, 	Top1_Acc: 0.109375, 	Top5_Acc: 0.259766
# Train Epoch: 8, Iteration: 9/390,  	Loss: 4.762383, 	Top1_Acc: 0.136719, 	Top5_Acc: 0.265625
# Train Epoch: 8, Iteration: 10/390,  	Loss: 4.752991, 	Top1_Acc: 0.085938, 	Top5_Acc: 0.269531
#
# Valid Epoch: 8, Iteration: 0/20,  	Loss: 4.792279, 	Top1_Acc: 0.138672, 	Top5_Acc: 0.314453
# Valid Epoch: 8, Iteration: 1/20,  	Loss: 4.798662, 	Top1_Acc: 0.144531, 	Top5_Acc: 0.304688
# Valid Epoch: 8, Iteration: 2/20,  	Loss: 4.939831, 	Top1_Acc: 0.091797, 	Top5_Acc: 0.273438
# Valid Epoch: 8, Iteration: 3/20,  	Loss: 4.901117, 	Top1_Acc: 0.154297, 	Top5_Acc: 0.287109
# Valid Epoch: 8, Iteration: 4/20,  	Loss: 4.944585, 	Top1_Acc: 0.123047, 	Top5_Acc: 0.263672
# Valid Epoch: 8, Iteration: 5/20,  	Loss: 4.817377, 	Top1_Acc: 0.152344, 	Top5_Acc: 0.291016
# Valid Epoch: 8, Iteration: 6/20,  	Loss: 4.830204, 	Top1_Acc: 0.123047, 	Top5_Acc: 0.255859
# Valid Epoch: 8, Iteration: 7/20,  	Loss: 4.857874, 	Top1_Acc: 0.128906, 	Top5_Acc: 0.281250
# Valid Epoch: 8, Iteration: 8/20,  	Loss: 4.740688, 	Top1_Acc: 0.123047, 	Top5_Acc: 0.298828
# Valid Epoch: 8, Iteration: 9/20,  	Loss: 4.769590, 	Top1_Acc: 0.111328, 	Top5_Acc: 0.265625
# Valid Epoch: 8, Iteration: 10/20,  	Loss: 4.882145, 	Top1_Acc: 0.134766, 	Top5_Acc: 0.285156
#
# Train Epoch: 9, Iteration: 0/390,  	Loss: 4.632926, 	Top1_Acc: 0.152344, 	Top5_Acc: 0.310547
# Train Epoch: 9, Iteration: 1/390,  	Loss: 4.734090, 	Top1_Acc: 0.119141, 	Top5_Acc: 0.271484
# Train Epoch: 9, Iteration: 2/390,  	Loss: 4.836209, 	Top1_Acc: 0.113281, 	Top5_Acc: 0.265625
# Train Epoch: 9, Iteration: 3/390,  	Loss: 4.738447, 	Top1_Acc: 0.136719, 	Top5_Acc: 0.291016
# Train Epoch: 9, Iteration: 4/390,  	Loss: 4.633097, 	Top1_Acc: 0.162109, 	Top5_Acc: 0.306641
# Train Epoch: 9, Iteration: 5/390,  	Loss: 4.589469, 	Top1_Acc: 0.140625, 	Top5_Acc: 0.332031
# Train Epoch: 9, Iteration: 6/390,  	Loss: 4.829552, 	Top1_Acc: 0.140625, 	Top5_Acc: 0.312500
# Train Epoch: 9, Iteration: 7/390,  	Loss: 4.748633, 	Top1_Acc: 0.146484, 	Top5_Acc: 0.339844
# Train Epoch: 9, Iteration: 8/390,  	Loss: 4.644452, 	Top1_Acc: 0.169922, 	Top5_Acc: 0.308594
# Train Epoch: 9, Iteration: 9/390,  	Loss: 4.694894, 	Top1_Acc: 0.158203, 	Top5_Acc: 0.306641
# Train Epoch: 9, Iteration: 10/390,  	Loss: 4.768018, 	Top1_Acc: 0.113281, 	Top5_Acc: 0.261719
#
# Valid Epoch: 9, Iteration: 0/20,  	Loss: 4.644128, 	Top1_Acc: 0.156250, 	Top5_Acc: 0.312500
# Valid Epoch: 9, Iteration: 1/20,  	Loss: 4.624858, 	Top1_Acc: 0.169922, 	Top5_Acc: 0.328125
# Valid Epoch: 9, Iteration: 2/20,  	Loss: 4.603656, 	Top1_Acc: 0.138672, 	Top5_Acc: 0.322266
# Valid Epoch: 9, Iteration: 3/20,  	Loss: 4.711941, 	Top1_Acc: 0.130859, 	Top5_Acc: 0.292969
# Valid Epoch: 9, Iteration: 4/20,  	Loss: 4.748145, 	Top1_Acc: 0.128906, 	Top5_Acc: 0.287109
# Valid Epoch: 9, Iteration: 5/20,  	Loss: 4.777684, 	Top1_Acc: 0.169922, 	Top5_Acc: 0.316406
# Valid Epoch: 9, Iteration: 6/20,  	Loss: 4.688009, 	Top1_Acc: 0.140625, 	Top5_Acc: 0.316406
# Valid Epoch: 9, Iteration: 7/20,  	Loss: 5.018839, 	Top1_Acc: 0.115234, 	Top5_Acc: 0.216797
# Valid Epoch: 9, Iteration: 8/20,  	Loss: 4.677294, 	Top1_Acc: 0.134766, 	Top5_Acc: 0.285156
# Valid Epoch: 9, Iteration: 9/20,  	Loss: 4.640298, 	Top1_Acc: 0.125000, 	Top5_Acc: 0.294922
# Valid Epoch: 9, Iteration: 10/20,  	Loss: 4.679317, 	Top1_Acc: 0.138672, 	Top5_Acc: 0.302734

# %%
# Let's plot the training and validation losses and Top-5 Accuracy
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

ax[0].plot(train_losses, label='Train Loss')
ax[0].plot(val_losses, label='Valid Loss')

ax[1].plot(train_top5_accs, label='Train Top-5 Accuracy')
ax[1].plot(val_top5_accs, label='Valid Top-5 Accuracy')

ax[0].set_title('Loss')
ax[1].set_title('Top-5 Accuracy')

for i in range(2):
    ax[i].legend()
    ax[i].grid()

plt.show()

# %% [markdown]
# As you can see we have just scratched the surface of the full training session.
#
# For running the next sections of this notebook, you can run the cell below to load the weights of the fully trained model. (You can ignore the cell instead if you  would like to test the model you personally trained).

# %%
## Load the pre-trained model here
## (Note: if you get an error here, you have some mistakes in the SimCLR model class definition.)
simclr_model.load_state_dict(torch.load(os.path.join(CHECKPOINT_PATH, "SimCLR.ckpt"))[ "state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# To get an intuition of how training with contrastive learning behaves, we can take a look at the TensorBoard below:

# %% [markdown]
# <center width="100%"><img src="https://github.com/phlippe/uvadlc_notebooks/blob/master/docs/tutorial_notebooks/tutorial17/tensorboard_simclr.png?raw=1" width="1200px"></center>
#
# One thing to note is that contrastive learning benefits a lot from long training. The shown plot above is from a training that took approximally 1 day on a NVIDIA TitanRTX. Training the model for even longer might reduce its loss further, but we did not experience any gains from it for the downstream task on image classification. In general, contrastive learning can also benefit from using larger models, if sufficient unlabeled data is available.

# %% [markdown]
# ## Downstream classification task
#
# After we have trained our model via contrastive learning, we can deploy it on downstream tasks and see how well it performs with little data. A common setup, which also verifies whether the model has learned generalized representations, is to perform classification on the features. In other words, we learn a single, linear layer that maps the representations to a class prediction. Since the base network $f(\cdot)$ is not changed during the training process, the model can only perform well if the representations of $h$ describe all features that might be necessary for the task. Further, we do not have to worry too much about overfitting since we have very few parameters that are trained. Hence, we might expect that the model can perform well even with very little data.
#
# First, let's implement a simple classification task setup for which we assume that the images already have been encoded in their feature vectors. If very little data is available, it might be beneficial to dynamically encode the images during training so that we can also apply data augmentations. However, the way we implement it here is much more efficient and can be trained within a few seconds. Further, using data augmentations did not show any significant gain in this simple setup.

# %%
class SimpleClassifier(nn.Module):

    def __init__(self, feature_dim, num_classes):
        super().__init__()

        # Mapping from representation h to classes with a linear layer
        self.model = nn.Linear(feature_dim, num_classes)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# The data we use is the training and test set of STL10. The training contains 500 images per class, while the test set has 800 images per class.

# %%
img_transforms = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.5,), (0.5,))])

train_img_data = STL10(root=DATASET_PATH, split='train', download=True,
                       transform=img_transforms)
test_img_data = STL10(root=DATASET_PATH, split='test', download=True,
                      transform=img_transforms)

print("Number of training examples:", len(train_img_data))
print("Number of test examples:", len(test_img_data))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of training examples: 5000
# Number of test examples: 8000

# %% [markdown]
# Next, we implement a small function to encode all images in our datasets. The output representations are then used as inputs to the classifier model.

# %%
@torch.no_grad()
def prepare_data_features(model, dataset):
    # Prepare model
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()  # Removing projection head g(.)
    network.eval()
    network.to(device)

    # Encode all images
    data_loader = data.DataLoader(dataset, batch_size=64, num_workers=NUM_WORKERS, shuffle=False, drop_last=False)
    feats, labels = [], []
    for batch_imgs, batch_labels in tqdm(data_loader):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        feats.append(batch_feats.detach().cpu())
        labels.append(batch_labels)

    feats = torch.cat(feats, dim=0)
    labels = torch.cat(labels, dim=0)

    # Sort images by labels
    labels, idxs = labels.sort()
    feats = feats[idxs]

    return data.TensorDataset(feats, labels)

# %% [markdown]
# Let's apply the function to both training and test set below.

# %%
train_feats_simclr = prepare_data_features(simclr_model, train_img_data)
test_feats_simclr = prepare_data_features(simclr_model, test_img_data)
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]

# %% [markdown]
# Finally, we can write a function to train this simple classifier on the SimCLR features. We evaluate the model on the test set every 10 epochs to allow early stopping, but the low frequency of the validation ensures that we do not overfit too much on the test set.

# %%
def train_classifier(batch_size, train_feats_data, test_feats_data, feature_dim, max_epochs=100):

    # Define the simple classifier model here, the number of classes in the dataset is 10
    model = SimpleClassifier(feature_dim, num_classes=10)
    model.to(device)

    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    # Data loaders
    train_loader = data.DataLoader(train_feats_data, batch_size=batch_size, shuffle=True,
                                   drop_last=False, pin_memory=True, num_workers=0)
    test_loader = data.DataLoader(test_feats_data, batch_size=batch_size, shuffle=False,
                                  drop_last=False, pin_memory=True, num_workers=0)

    tlosses = []
    taccs = []

    best_test_acc = 0
    model.train()
    for epoch in range(max_epochs):
        losses = []
        accs = []
        for batch in train_loader:
            feats, labels = batch
            feats = feats.to(device)
            labels = labels.to(device)

            # Forward pass
            preds = model(feats)

            # Compute the cross entropy loss
            loss = F.cross_entropy(preds, labels)

            acc = (preds.argmax(dim=-1) == labels).float().mean()

            losses.append(loss.item())
            accs.append(acc.item())

            # Backpropagate the loss and perform the optimization step
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        tlosses.append(np.mean(losses))
        taccs.append(np.mean(accs))

        print(f"Epoch: {epoch}, Train Loss: {tlosses[-1]:.6f}, Train Accuracy: {taccs[-1]:.6f}")

        if epoch%10 == 0:
            ## Test set
            print()
            test_acc = []
            model.eval()
            with torch.no_grad():
                for batch in test_loader:
                    feats, labels = batch
                    feats = feats.to(device)
                    labels = labels.to(device)

                    # Forward pass
                    preds = model(feats)
                    acc = (preds.argmax(dim=-1) == labels).float().mean()
                    test_acc.append(acc.item())

                test_acc = np.mean(test_acc)
                if test_acc > best_test_acc:
                    best_test_acc = test_acc.item()
                else:
                    print("Early stop at epoch ", epoch)
                    break

    return model, best_test_acc

# %% [markdown]
# Despite the training dataset of STL10 already only having 500 labeled images per class, we will perform experiments with even smaller datasets. Specifically, we train a Logistic Regression model for datasets with only 10, 20, 50, 100, 200, and all 500 examples per class. This gives us an intuition on how well the representations learned by contrastive learning can be transfered to a image recognition task like this classification. First, let's define a function to create the intended sub-datasets from the full training set:

# %%
def get_smaller_dataset(original_dataset, num_imgs_per_label):
    new_dataset = data.TensorDataset(
        *[t.unflatten(0, (10, -1))[:,:num_imgs_per_label].flatten(0, 1) for t in original_dataset.tensors]
    )
    return new_dataset

# %% [markdown]
# Next, let's run all models. Despite us training 6 models, this cell could be run within a minute or two without the pretrained models.

# %%
batch_size=64
feature_dim=train_feats_simclr.tensors[0].shape[1]
num_classes=10
lr=1e-3
weight_decay=1e-3

results = {}
for num_imgs_per_label in [10, 20, 50, 100, 200, 500]:
    sub_train_set = get_smaller_dataset(train_feats_simclr, num_imgs_per_label)
    _, small_set_results = train_classifier(batch_size=64,
                                        train_feats_data=sub_train_set,
                                        test_feats_data=test_feats_simclr,
                                        feature_dim=train_feats_simclr.tensors[0].shape[1])
    results[num_imgs_per_label] = small_set_results
# Out:
# Epoch: 0, Train Loss: 2.398340, Train Accuracy: 0.065104
#
# Epoch: 1, Train Loss: 2.173398, Train Accuracy: 0.199653
# Epoch: 2, Train Loss: 1.983118, Train Accuracy: 0.350694
# Epoch: 3, Train Loss: 1.846991, Train Accuracy: 0.447049
# Epoch: 4, Train Loss: 1.692697, Train Accuracy: 0.522569
# Epoch: 5, Train Loss: 1.550305, Train Accuracy: 0.668403
# Epoch: 6, Train Loss: 1.462490, Train Accuracy: 0.720486
# Epoch: 7, Train Loss: 1.323948, Train Accuracy: 0.789931
# Epoch: 8, Train Loss: 1.265196, Train Accuracy: 0.763021
# Epoch: 9, Train Loss: 1.169424, Train Accuracy: 0.787326
# Epoch: 10, Train Loss: 1.052461, Train Accuracy: 0.825521
#
# Epoch: 11, Train Loss: 1.036675, Train Accuracy: 0.846354
# Epoch: 12, Train Loss: 0.945683, Train Accuracy: 0.855903
# Epoch: 13, Train Loss: 0.872272, Train Accuracy: 0.892361
# Epoch: 14, Train Loss: 0.842232, Train Accuracy: 0.869792
# Epoch: 15, Train Loss: 0.796638, Train Accuracy: 0.875868
# Epoch: 16, Train Loss: 0.727327, Train Accuracy: 0.901910
# Epoch: 17, Train Loss: 0.688775, Train Accuracy: 0.919271
# Epoch: 18, Train Loss: 0.656409, Train Accuracy: 0.907118
# Epoch: 19, Train Loss: 0.615089, Train Accuracy: 0.917535
# Epoch: 20, Train Loss: 0.590435, Train Accuracy: 0.954861
#
# Epoch: 21, Train Loss: 0.546980, Train Accuracy: 0.968750
# Epoch: 22, Train Loss: 0.542821, Train Accuracy: 0.976562
# Epoch: 23, Train Loss: 0.503665, Train Accuracy: 0.970486
# Epoch: 24, Train Loss: 0.475997, Train Accuracy: 0.978299
# Epoch: 25, Train Loss: 0.452680, Train Accuracy: 0.978299
# Epoch: 26, Train Loss: 0.445173, Train Accuracy: 0.992188
# Epoch: 27, Train Loss: 0.423385, Train Accuracy: 1.000000
# Epoch: 28, Train Loss: 0.404435, Train Accuracy: 1.000000
# Epoch: 29, Train Loss: 0.381632, Train Accuracy: 1.000000
# Epoch: 30, Train Loss: 0.376674, Train Accuracy: 1.000000
#
# Epoch: 31, Train Loss: 0.358614, Train Accuracy: 1.000000
# Epoch: 32, Train Loss: 0.340011, Train Accuracy: 1.000000
# Epoch: 33, Train Loss: 0.328028, Train Accuracy: 1.000000
# Epoch: 34, Train Loss: 0.310250, Train Accuracy: 1.000000
# Epoch: 35, Train Loss: 0.291721, Train Accuracy: 1.000000
# Epoch: 36, Train Loss: 0.296293, Train Accuracy: 1.000000
# Epoch: 37, Train Loss: 0.276972, Train Accuracy: 1.000000
# Epoch: 38, Train Loss: 0.270448, Train Accuracy: 1.000000
# Epoch: 39, Train Loss: 0.275059, Train Accuracy: 1.000000
# Epoch: 40, Train Loss: 0.247774, Train Accuracy: 1.000000
#
# Epoch: 41, Train Loss: 0.240729, Train Accuracy: 1.000000
# Epoch: 42, Train Loss: 0.241296, Train Accuracy: 1.000000
# Epoch: 43, Train Loss: 0.223100, Train Accuracy: 1.000000
# Epoch: 44, Train Loss: 0.216947, Train Accuracy: 1.000000
# Epoch: 45, Train Loss: 0.210584, Train Accuracy: 1.000000
# Epoch: 46, Train Loss: 0.213801, Train Accuracy: 1.000000
# Epoch: 47, Train Loss: 0.204391, Train Accuracy: 1.000000
# Epoch: 48, Train Loss: 0.194956, Train Accuracy: 1.000000
# Epoch: 49, Train Loss: 0.192763, Train Accuracy: 1.000000
# Epoch: 50, Train Loss: 0.186704, Train Accuracy: 1.000000
#
# Epoch: 51, Train Loss: 0.182721, Train Accuracy: 1.000000
# Epoch: 52, Train Loss: 0.176462, Train Accuracy: 1.000000
# Epoch: 53, Train Loss: 0.168782, Train Accuracy: 1.000000
# Epoch: 54, Train Loss: 0.160229, Train Accuracy: 1.000000
# Epoch: 55, Train Loss: 0.155764, Train Accuracy: 1.000000
# Epoch: 56, Train Loss: 0.147929, Train Accuracy: 1.000000
# Epoch: 57, Train Loss: 0.154304, Train Accuracy: 1.000000
# Epoch: 58, Train Loss: 0.146016, Train Accuracy: 1.000000
# Epoch: 59, Train Loss: 0.146463, Train Accuracy: 1.000000
# Epoch: 60, Train Loss: 0.145008, Train Accuracy: 1.000000
#
# Early stop at epoch  60
# Epoch: 0, Train Loss: 2.385108, Train Accuracy: 0.140625
#
# Epoch: 1, Train Loss: 2.027871, Train Accuracy: 0.277344
# Epoch: 2, Train Loss: 1.780938, Train Accuracy: 0.445312
# Epoch: 3, Train Loss: 1.614018, Train Accuracy: 0.546875
# Epoch: 4, Train Loss: 1.407281, Train Accuracy: 0.660156
# Epoch: 5, Train Loss: 1.359210, Train Accuracy: 0.660156
# Epoch: 6, Train Loss: 1.205895, Train Accuracy: 0.714844
# Epoch: 7, Train Loss: 1.137507, Train Accuracy: 0.757812
# Epoch: 8, Train Loss: 1.037253, Train Accuracy: 0.855469
# Epoch: 9, Train Loss: 0.927348, Train Accuracy: 0.828125
# Epoch: 10, Train Loss: 0.892153, Train Accuracy: 0.828125
#
# Epoch: 11, Train Loss: 0.831326, Train Accuracy: 0.839844
# Epoch: 12, Train Loss: 0.777943, Train Accuracy: 0.863281
# Epoch: 13, Train Loss: 0.720452, Train Accuracy: 0.851562
# Epoch: 14, Train Loss: 0.685148, Train Accuracy: 0.914062
# Epoch: 15, Train Loss: 0.664354, Train Accuracy: 0.914062
# Epoch: 16, Train Loss: 0.633460, Train Accuracy: 0.878906
# Epoch: 17, Train Loss: 0.600525, Train Accuracy: 0.886719
# Epoch: 18, Train Loss: 0.557135, Train Accuracy: 0.921875
# Epoch: 19, Train Loss: 0.529428, Train Accuracy: 0.917969
# Epoch: 20, Train Loss: 0.578131, Train Accuracy: 0.894531
#
# Epoch: 21, Train Loss: 0.536824, Train Accuracy: 0.906250
# Epoch: 22, Train Loss: 0.511905, Train Accuracy: 0.937500
# Epoch: 23, Train Loss: 0.438322, Train Accuracy: 0.953125
# Epoch: 24, Train Loss: 0.465155, Train Accuracy: 0.929688
# Epoch: 25, Train Loss: 0.438647, Train Accuracy: 0.945312
# Epoch: 26, Train Loss: 0.465550, Train Accuracy: 0.921875
# Epoch: 27, Train Loss: 0.422692, Train Accuracy: 0.960938
# Epoch: 28, Train Loss: 0.376538, Train Accuracy: 0.953125
# Epoch: 29, Train Loss: 0.409234, Train Accuracy: 0.921875
# Epoch: 30, Train Loss: 0.333367, Train Accuracy: 0.953125
#
# Epoch: 31, Train Loss: 0.335445, Train Accuracy: 0.957031
# Epoch: 32, Train Loss: 0.374115, Train Accuracy: 0.972656
# Epoch: 33, Train Loss: 0.342881, Train Accuracy: 0.968750
# Epoch: 34, Train Loss: 0.323829, Train Accuracy: 0.964844
# Epoch: 35, Train Loss: 0.324085, Train Accuracy: 0.960938
# Epoch: 36, Train Loss: 0.371477, Train Accuracy: 0.937500
# Epoch: 37, Train Loss: 0.347407, Train Accuracy: 0.968750
# Epoch: 38, Train Loss: 0.307254, Train Accuracy: 0.984375
# Epoch: 39, Train Loss: 0.321034, Train Accuracy: 0.984375
# Epoch: 40, Train Loss: 0.281631, Train Accuracy: 0.980469
#
# Early stop at epoch  40
# Epoch: 0, Train Loss: 2.239771, Train Accuracy: 0.185547
#
# Epoch: 1, Train Loss: 1.784713, Train Accuracy: 0.414964
# Epoch: 2, Train Loss: 1.456853, Train Accuracy: 0.619291
# Epoch: 3, Train Loss: 1.227810, Train Accuracy: 0.696364
# Epoch: 4, Train Loss: 1.058771, Train Accuracy: 0.747746
# Epoch: 5, Train Loss: 0.949599, Train Accuracy: 0.778696
# Epoch: 6, Train Loss: 0.852102, Train Accuracy: 0.787861
# Epoch: 7, Train Loss: 0.786337, Train Accuracy: 0.789513
# Epoch: 8, Train Loss: 0.720361, Train Accuracy: 0.825421
# Epoch: 9, Train Loss: 0.682301, Train Accuracy: 0.836238
# Epoch: 10, Train Loss: 0.639419, Train Accuracy: 0.834886
#
# Epoch: 11, Train Loss: 0.608951, Train Accuracy: 0.839243
# Epoch: 12, Train Loss: 0.579719, Train Accuracy: 0.847055
# Epoch: 13, Train Loss: 0.551859, Train Accuracy: 0.852915
# Epoch: 14, Train Loss: 0.524226, Train Accuracy: 0.871695
# Epoch: 15, Train Loss: 0.504190, Train Accuracy: 0.878155
# Epoch: 16, Train Loss: 0.482425, Train Accuracy: 0.887770
# Epoch: 17, Train Loss: 0.468241, Train Accuracy: 0.885968
# Epoch: 18, Train Loss: 0.450296, Train Accuracy: 0.890925
# Epoch: 19, Train Loss: 0.431403, Train Accuracy: 0.910306
# Epoch: 20, Train Loss: 0.415736, Train Accuracy: 0.904898
#
# Epoch: 21, Train Loss: 0.400014, Train Accuracy: 0.913161
# Epoch: 22, Train Loss: 0.387305, Train Accuracy: 0.926833
# Epoch: 23, Train Loss: 0.376896, Train Accuracy: 0.928786
# Epoch: 24, Train Loss: 0.368150, Train Accuracy: 0.925931
# Epoch: 25, Train Loss: 0.353168, Train Accuracy: 0.940956
# Epoch: 26, Train Loss: 0.340080, Train Accuracy: 0.945463
# Epoch: 27, Train Loss: 0.335452, Train Accuracy: 0.946965
# Epoch: 28, Train Loss: 0.324503, Train Accuracy: 0.943960
# Epoch: 29, Train Loss: 0.312754, Train Accuracy: 0.952224
# Epoch: 30, Train Loss: 0.303880, Train Accuracy: 0.959585
#
# Epoch: 31, Train Loss: 0.293959, Train Accuracy: 0.960036
# Epoch: 32, Train Loss: 0.285804, Train Accuracy: 0.963942
# Epoch: 33, Train Loss: 0.278706, Train Accuracy: 0.969802
# Epoch: 34, Train Loss: 0.273045, Train Accuracy: 0.971755
# Epoch: 35, Train Loss: 0.264647, Train Accuracy: 0.965445
# Epoch: 36, Train Loss: 0.258184, Train Accuracy: 0.976562
# Epoch: 37, Train Loss: 0.251537, Train Accuracy: 0.977614
# Epoch: 38, Train Loss: 0.245968, Train Accuracy: 0.972656
# Epoch: 39, Train Loss: 0.237735, Train Accuracy: 0.980469
# Epoch: 40, Train Loss: 0.233112, Train Accuracy: 0.981971
#
# Epoch: 41, Train Loss: 0.226887, Train Accuracy: 0.981971
# Epoch: 42, Train Loss: 0.221683, Train Accuracy: 0.987831
# Epoch: 43, Train Loss: 0.217331, Train Accuracy: 0.986328
# Epoch: 44, Train Loss: 0.213576, Train Accuracy: 0.987380
# Epoch: 45, Train Loss: 0.205967, Train Accuracy: 0.988281
# Epoch: 46, Train Loss: 0.201832, Train Accuracy: 0.990234
# Epoch: 47, Train Loss: 0.198319, Train Accuracy: 0.988281
# Epoch: 48, Train Loss: 0.191872, Train Accuracy: 0.990234
# Epoch: 49, Train Loss: 0.189766, Train Accuracy: 0.990234
# Epoch: 50, Train Loss: 0.184355, Train Accuracy: 0.992188
#
# Early stop at epoch  50
# Epoch: 0, Train Loss: 1.900977, Train Accuracy: 0.362891
#
# Epoch: 1, Train Loss: 1.309973, Train Accuracy: 0.668555
# Epoch: 2, Train Loss: 1.011254, Train Accuracy: 0.738672
# Epoch: 3, Train Loss: 0.853730, Train Accuracy: 0.778711
# Epoch: 4, Train Loss: 0.755108, Train Accuracy: 0.795898
# Epoch: 5, Train Loss: 0.688557, Train Accuracy: 0.804883
# Epoch: 6, Train Loss: 0.636775, Train Accuracy: 0.827539
# Epoch: 7, Train Loss: 0.599512, Train Accuracy: 0.831641
# Epoch: 8, Train Loss: 0.570135, Train Accuracy: 0.829102
# Epoch: 9, Train Loss: 0.534084, Train Accuracy: 0.846289
# Epoch: 10, Train Loss: 0.515379, Train Accuracy: 0.849609
#
# Epoch: 11, Train Loss: 0.495449, Train Accuracy: 0.856250
# Epoch: 12, Train Loss: 0.474552, Train Accuracy: 0.868164
# Epoch: 13, Train Loss: 0.455416, Train Accuracy: 0.874609
# Epoch: 14, Train Loss: 0.438564, Train Accuracy: 0.881055
# Epoch: 15, Train Loss: 0.425438, Train Accuracy: 0.873047
# Epoch: 16, Train Loss: 0.411947, Train Accuracy: 0.888281
# Epoch: 17, Train Loss: 0.401553, Train Accuracy: 0.888086
# Epoch: 18, Train Loss: 0.387925, Train Accuracy: 0.891016
# Epoch: 19, Train Loss: 0.376665, Train Accuracy: 0.896094
# Epoch: 20, Train Loss: 0.363395, Train Accuracy: 0.906055
#
# Epoch: 21, Train Loss: 0.355298, Train Accuracy: 0.908398
# Epoch: 22, Train Loss: 0.343968, Train Accuracy: 0.908398
# Epoch: 23, Train Loss: 0.338765, Train Accuracy: 0.909180
# Epoch: 24, Train Loss: 0.330850, Train Accuracy: 0.914648
# Epoch: 25, Train Loss: 0.324396, Train Accuracy: 0.916016
# Epoch: 26, Train Loss: 0.313670, Train Accuracy: 0.919531
# Epoch: 27, Train Loss: 0.302858, Train Accuracy: 0.925586
# Epoch: 28, Train Loss: 0.302815, Train Accuracy: 0.919727
# Epoch: 29, Train Loss: 0.291759, Train Accuracy: 0.927148
# Epoch: 30, Train Loss: 0.284453, Train Accuracy: 0.928516
#
# Epoch: 31, Train Loss: 0.279754, Train Accuracy: 0.934570
# Epoch: 32, Train Loss: 0.272631, Train Accuracy: 0.932813
# Epoch: 33, Train Loss: 0.270885, Train Accuracy: 0.936719
# Epoch: 34, Train Loss: 0.260074, Train Accuracy: 0.940625
# Epoch: 35, Train Loss: 0.254368, Train Accuracy: 0.941016
# Epoch: 36, Train Loss: 0.247876, Train Accuracy: 0.947070
# Epoch: 37, Train Loss: 0.247178, Train Accuracy: 0.946484
# Epoch: 38, Train Loss: 0.239316, Train Accuracy: 0.950586
# Epoch: 39, Train Loss: 0.241346, Train Accuracy: 0.946680
# Epoch: 40, Train Loss: 0.234321, Train Accuracy: 0.950000
#
# Epoch: 41, Train Loss: 0.228377, Train Accuracy: 0.955859
# Epoch: 42, Train Loss: 0.221097, Train Accuracy: 0.961133
# Epoch: 43, Train Loss: 0.216766, Train Accuracy: 0.960742
# Epoch: 44, Train Loss: 0.214548, Train Accuracy: 0.960547
# Epoch: 45, Train Loss: 0.208301, Train Accuracy: 0.960352
# Epoch: 46, Train Loss: 0.205398, Train Accuracy: 0.968555
# Epoch: 47, Train Loss: 0.201117, Train Accuracy: 0.962695
# Epoch: 48, Train Loss: 0.195408, Train Accuracy: 0.972656
# Epoch: 49, Train Loss: 0.194968, Train Accuracy: 0.970508
# Epoch: 50, Train Loss: 0.191135, Train Accuracy: 0.971094
#
# Early stop at epoch  50
# Epoch: 0, Train Loss: 1.702234, Train Accuracy: 0.465332
#
# Epoch: 1, Train Loss: 1.027149, Train Accuracy: 0.724609
# Epoch: 2, Train Loss: 0.813852, Train Accuracy: 0.761719
# Epoch: 3, Train Loss: 0.708270, Train Accuracy: 0.782227
# Epoch: 4, Train Loss: 0.653546, Train Accuracy: 0.791504
# Epoch: 5, Train Loss: 0.610620, Train Accuracy: 0.804688
# Epoch: 6, Train Loss: 0.585194, Train Accuracy: 0.808105
# Epoch: 7, Train Loss: 0.558574, Train Accuracy: 0.814453
# Epoch: 8, Train Loss: 0.529495, Train Accuracy: 0.824219
# Epoch: 9, Train Loss: 0.510960, Train Accuracy: 0.834473
# Epoch: 10, Train Loss: 0.488189, Train Accuracy: 0.842285
#
# Epoch: 11, Train Loss: 0.486302, Train Accuracy: 0.841309
# Epoch: 12, Train Loss: 0.462831, Train Accuracy: 0.850586
# Epoch: 13, Train Loss: 0.443401, Train Accuracy: 0.861816
# Epoch: 14, Train Loss: 0.434436, Train Accuracy: 0.858398
# Epoch: 15, Train Loss: 0.427559, Train Accuracy: 0.863281
# Epoch: 16, Train Loss: 0.419653, Train Accuracy: 0.860352
# Epoch: 17, Train Loss: 0.407778, Train Accuracy: 0.868652
# Epoch: 18, Train Loss: 0.405347, Train Accuracy: 0.869629
# Epoch: 19, Train Loss: 0.400351, Train Accuracy: 0.877441
# Epoch: 20, Train Loss: 0.379239, Train Accuracy: 0.876953
#
# Epoch: 21, Train Loss: 0.370852, Train Accuracy: 0.886230
# Epoch: 22, Train Loss: 0.363086, Train Accuracy: 0.887207
# Epoch: 23, Train Loss: 0.354398, Train Accuracy: 0.889160
# Epoch: 24, Train Loss: 0.358736, Train Accuracy: 0.883789
# Epoch: 25, Train Loss: 0.349760, Train Accuracy: 0.891602
# Epoch: 26, Train Loss: 0.341406, Train Accuracy: 0.895020
# Epoch: 27, Train Loss: 0.338325, Train Accuracy: 0.895020
# Epoch: 28, Train Loss: 0.334034, Train Accuracy: 0.900391
# Epoch: 29, Train Loss: 0.324228, Train Accuracy: 0.896484
# Epoch: 30, Train Loss: 0.313569, Train Accuracy: 0.904297
#
# Early stop at epoch  30
# Epoch: 0, Train Loss: 1.281296, Train Accuracy: 0.616100
#
# Epoch: 1, Train Loss: 0.748521, Train Accuracy: 0.761472
# Epoch: 2, Train Loss: 0.636338, Train Accuracy: 0.788568
# Epoch: 3, Train Loss: 0.584971, Train Accuracy: 0.802611
# Epoch: 4, Train Loss: 0.550527, Train Accuracy: 0.810720
# Epoch: 5, Train Loss: 0.524403, Train Accuracy: 0.820609
# Epoch: 6, Train Loss: 0.504847, Train Accuracy: 0.827729
# Epoch: 7, Train Loss: 0.489357, Train Accuracy: 0.833861
# Epoch: 8, Train Loss: 0.468856, Train Accuracy: 0.839794
# Epoch: 9, Train Loss: 0.459999, Train Accuracy: 0.841772
# Epoch: 10, Train Loss: 0.454037, Train Accuracy: 0.842959
#
# Epoch: 11, Train Loss: 0.445890, Train Accuracy: 0.842563
# Epoch: 12, Train Loss: 0.432323, Train Accuracy: 0.851068
# Epoch: 13, Train Loss: 0.425210, Train Accuracy: 0.855419
# Epoch: 14, Train Loss: 0.420263, Train Accuracy: 0.851068
# Epoch: 15, Train Loss: 0.414942, Train Accuracy: 0.854628
# Epoch: 16, Train Loss: 0.408507, Train Accuracy: 0.858782
# Epoch: 17, Train Loss: 0.401410, Train Accuracy: 0.859177
# Epoch: 18, Train Loss: 0.393568, Train Accuracy: 0.865506
# Epoch: 19, Train Loss: 0.385264, Train Accuracy: 0.866100
# Epoch: 20, Train Loss: 0.380242, Train Accuracy: 0.865704
#
# Epoch: 21, Train Loss: 0.381255, Train Accuracy: 0.865309
# Epoch: 22, Train Loss: 0.381679, Train Accuracy: 0.864715
# Epoch: 23, Train Loss: 0.367069, Train Accuracy: 0.870649
# Epoch: 24, Train Loss: 0.363971, Train Accuracy: 0.874011
# Epoch: 25, Train Loss: 0.359232, Train Accuracy: 0.875000
# Epoch: 26, Train Loss: 0.353300, Train Accuracy: 0.876780
# Epoch: 27, Train Loss: 0.356429, Train Accuracy: 0.872033
# Epoch: 28, Train Loss: 0.346904, Train Accuracy: 0.877967
# Epoch: 29, Train Loss: 0.346203, Train Accuracy: 0.880340
# Epoch: 30, Train Loss: 0.338144, Train Accuracy: 0.886867
#
# Epoch: 31, Train Loss: 0.336781, Train Accuracy: 0.883505
# Epoch: 32, Train Loss: 0.328249, Train Accuracy: 0.887460
# Epoch: 33, Train Loss: 0.328076, Train Accuracy: 0.887856
# Epoch: 34, Train Loss: 0.329203, Train Accuracy: 0.885878
# Epoch: 35, Train Loss: 0.321207, Train Accuracy: 0.889241
# Epoch: 36, Train Loss: 0.320365, Train Accuracy: 0.892998
# Epoch: 37, Train Loss: 0.314536, Train Accuracy: 0.896163
# Epoch: 38, Train Loss: 0.311275, Train Accuracy: 0.895965
# Epoch: 39, Train Loss: 0.313678, Train Accuracy: 0.895174
# Epoch: 40, Train Loss: 0.309933, Train Accuracy: 0.895570
#
# Epoch: 41, Train Loss: 0.306864, Train Accuracy: 0.897547
# Epoch: 42, Train Loss: 0.312295, Train Accuracy: 0.897943
# Epoch: 43, Train Loss: 0.296670, Train Accuracy: 0.899525
# Epoch: 44, Train Loss: 0.294644, Train Accuracy: 0.901503
# Epoch: 45, Train Loss: 0.292912, Train Accuracy: 0.900712
# Epoch: 46, Train Loss: 0.293197, Train Accuracy: 0.903877
# Epoch: 47, Train Loss: 0.286298, Train Accuracy: 0.905657
# Epoch: 48, Train Loss: 0.287215, Train Accuracy: 0.903481
# Epoch: 49, Train Loss: 0.284767, Train Accuracy: 0.906448
# Epoch: 50, Train Loss: 0.280941, Train Accuracy: 0.904668
#
# Early stop at epoch  50

# %% [markdown]
# Finally, let's plot the results.

# %%
dataset_sizes = sorted([k for k in results])
test_scores = [results[k] for k in dataset_sizes]

fig = plt.figure(figsize=(6,4))
plt.plot(dataset_sizes, test_scores, '--', color="#000", marker="*", markeredgecolor="#000", markerfacecolor="y", markersize=16)
plt.xscale("log")
plt.xticks(dataset_sizes, labels=dataset_sizes)
plt.title("STL10 classification over dataset size", fontsize=14)
plt.xlabel("Number of images per class")
plt.ylabel("Test accuracy")
plt.minorticks_off()
plt.show()

for k, score in zip(dataset_sizes, test_scores):
    print(f'Test accuracy for {k:3d} images per label: {100*score:4.2f}%')
# Out:
# Test accuracy for  10 images per label: 62.25%
# Test accuracy for  20 images per label: 68.49%
# Test accuracy for  50 images per label: 74.26%
# Test accuracy for 100 images per label: 77.18%
# Test accuracy for 200 images per label: 79.09%
# Test accuracy for 500 images per label: 81.34%

# %% [markdown]
# As one would expect, the classification performance improves the more data we have. However, with only 10 images per class, we can already classify more than 60% of the images correctly. This is quite impressive, considering that the images are also higher dimensional than e.g. CIFAR10. With the full dataset, we achieve an accuracy of 81%. The increase between 50 to 500 images per class might suggest a linear increase in performance with an exponentially larger dataset. However, with even more data, we could also finetune $f(\cdot)$ in the training process, allowing for the representations to adapt more to the specific classification task given.
#
# To set the results above into perspective, we will train the base network, a ResNet-18, on the classification task from scratch.

# %% [markdown]
# ## Baseline
#
# As a baseline to our results above, we will train a standard ResNet-18 with random initialization on the labeled training set of STL10. The results will give us an indication of the advantages that contrastive learning on unlabeled data has compared to using only supervised training. The implementation of the model is straightforward since the ResNet architecture is provided in the torchvision library.

# %%
class ResNet(nn.Module):

    def __init__(self, num_classes):
        super().__init__()
        self.model = torchvision.models.resnet18(num_classes=num_classes)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# It is clear that the ResNet easily overfits on the training data since its parameter count is more than 1000 times larger than the dataset size. To make the comparison to the contrastive learning models fair, we apply data augmentations similar to the ones we used before: horizontal flip, crop-and-resize, grayscale, and gaussian blur. Color distortions as before are not used because the color distribution of an image showed to be an important feature for the classification. Hence, we observed no noticeable performance gains when adding color distortions to the set of augmentations. Similarly, we restrict the resizing operation before cropping to the max. 125% of its original resolution, instead of 1250% as done in SimCLR. This is because, for classification, the model needs to recognize the full object, while in contrastive learning, we only want to check whether two patches belong to the same image/object. Hence, the chosen augmentations below are overall weaker than in the contrastive learning case.

# %%
train_transforms = transforms.Compose([transforms.RandomHorizontalFlip(),
                                       transforms.RandomResizedCrop(size=96, scale=(0.8, 1.0)),
                                       transforms.RandomGrayscale(p=0.2),
                                       transforms.GaussianBlur(kernel_size=9, sigma=(0.1, 0.5)),
                                       transforms.ToTensor(),
                                       transforms.Normalize((0.5,), (0.5,))
                                       ])

train_img_aug_data = STL10(root=DATASET_PATH, split='train', download=True, transform=train_transforms)
# Out:
# Files already downloaded and verified

# %% [markdown]
# The training function for the ResNet is almost identical to the Logistic Regression setup. Note that we allow the ResNet to perform validation every 2 epochs to also check whether the model overfits strongly in the first iterations or not.

# %%
def train_resnet(batch_size, lr, weight_decay, max_epochs=100):

    model = ResNet(num_classes=10)
    model.to(device)

    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    lr_scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[int(max_epochs*0.7), int(max_epochs*0.9)], gamma=0.1)

    # Data loaders
    train_loader = data.DataLoader(train_img_aug_data, batch_size=batch_size, shuffle=True,
                                   drop_last=True, pin_memory=True, num_workers=NUM_WORKERS)

    test_loader = data.DataLoader(test_img_data, batch_size=batch_size, shuffle=False,
                                  drop_last=False, pin_memory=True, num_workers=NUM_WORKERS)

    tlosses = []
    taccs = []
    best_test_acc = 0
    for epoch in range(max_epochs):
        model.train()
        for batch in train_loader:
            losses = []
            accs = []

            imgs, labels = batch
            imgs = imgs.to(device)
            labels = labels.to(device)

            # Forward pass
            preds = model(imgs)

            # Cross entropy loss
            loss = F.cross_entropy(preds, labels)
            acc = (preds.argmax(dim=-1) == labels).float().mean()

            losses.append(loss.item())
            accs.append(acc.item())

            # Error backpropagation and optimization step
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        lr_scheduler.step()

        tlosses.append(np.mean(losses))
        taccs.append(np.mean(accs))

        print(f"Epoch: {epoch}, Train Loss: {tlosses[-1]:.6f}, Train Accuracy: {taccs[-1]:.6f}")

        if epoch%5 == 0:
            ## Test set
            test_acc = []
            model.eval()
            with torch.no_grad():
                for batch in test_loader:
                    imgs, labels = batch
                    imgs = imgs.to(device)
                    labels = labels.to(device)

                    # Forward pass
                    preds = model(imgs)

                    acc = (preds.argmax(dim=-1) == labels).float().mean()
                    test_acc.append(acc.item())

                test_acc = np.mean(test_acc)

                print(f"Epoch: {epoch}, Test Accuracy: {best_test_acc:.6f}")
                if test_acc >= best_test_acc:
                    best_test_acc = test_acc.item()

    return model, best_test_acc

# %% [markdown]
# Finally, let's train the model and check its results.
#
# Please note that also in this case, the training procedure is quite long. On Google Colab, it will require approximately ~30 minutes to run.

# %%
resnet_model, best_test_acc = train_resnet(batch_size=64,
                                           lr=1e-3,
                                           weight_decay=2e-4,
                                           max_epochs=100)

# print(f"Accuracy on training set: {100*train_acc:4.2f}%")
print()

print(f"Accuracy on test set: {100*best_test_acc:4.2f}%")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch: 0, Train Loss: 1.325549, Train Accuracy: 0.500000
# Epoch: 0, Test Accuracy: 0.000000
# Epoch: 1, Train Loss: 1.612558, Train Accuracy: 0.390625
# Epoch: 2, Train Loss: 1.735340, Train Accuracy: 0.359375
# Epoch: 3, Train Loss: 1.454493, Train Accuracy: 0.437500
# Epoch: 4, Train Loss: 1.131301, Train Accuracy: 0.640625
# Epoch: 5, Train Loss: 1.244166, Train Accuracy: 0.562500
# Epoch: 5, Test Accuracy: 0.383625
# Epoch: 6, Train Loss: 1.130516, Train Accuracy: 0.578125
# Epoch: 7, Train Loss: 0.735758, Train Accuracy: 0.750000
# Epoch: 8, Train Loss: 0.993335, Train Accuracy: 0.640625
# Epoch: 9, Train Loss: 0.699651, Train Accuracy: 0.781250
# Epoch: 10, Train Loss: 0.871458, Train Accuracy: 0.703125
# Epoch: 10, Test Accuracy: 0.519625
# Epoch: 11, Train Loss: 0.896516, Train Accuracy: 0.734375
# Epoch: 12, Train Loss: 0.697690, Train Accuracy: 0.750000
# Epoch: 13, Train Loss: 0.577516, Train Accuracy: 0.828125
# Epoch: 14, Train Loss: 0.663485, Train Accuracy: 0.718750
# Epoch: 15, Train Loss: 0.648836, Train Accuracy: 0.781250
# Epoch: 15, Test Accuracy: 0.634250
# Epoch: 16, Train Loss: 0.440906, Train Accuracy: 0.859375
# Epoch: 17, Train Loss: 0.695428, Train Accuracy: 0.734375
# Epoch: 18, Train Loss: 0.345055, Train Accuracy: 0.875000
# Epoch: 19, Train Loss: 0.602122, Train Accuracy: 0.828125
# Epoch: 20, Train Loss: 0.591025, Train Accuracy: 0.781250
# Epoch: 20, Test Accuracy: 0.668375
# Epoch: 21, Train Loss: 0.475217, Train Accuracy: 0.843750
# Epoch: 22, Train Loss: 0.409246, Train Accuracy: 0.828125
# Epoch: 23, Train Loss: 0.340712, Train Accuracy: 0.875000
# Epoch: 24, Train Loss: 0.266629, Train Accuracy: 0.890625
# Epoch: 25, Train Loss: 0.375795, Train Accuracy: 0.875000
# Epoch: 25, Test Accuracy: 0.668375
# Epoch: 26, Train Loss: 0.406757, Train Accuracy: 0.859375
# Epoch: 27, Train Loss: 0.196161, Train Accuracy: 0.937500
# Epoch: 28, Train Loss: 0.215296, Train Accuracy: 0.906250
# Epoch: 29, Train Loss: 0.243019, Train Accuracy: 0.921875
# Epoch: 30, Train Loss: 0.195752, Train Accuracy: 0.937500
# Epoch: 30, Test Accuracy: 0.668375
# Epoch: 31, Train Loss: 0.124025, Train Accuracy: 0.968750
# Epoch: 32, Train Loss: 0.174287, Train Accuracy: 0.906250
# Epoch: 33, Train Loss: 0.256976, Train Accuracy: 0.906250
# Epoch: 34, Train Loss: 0.144819, Train Accuracy: 0.953125
# Epoch: 35, Train Loss: 0.103746, Train Accuracy: 0.984375
# Epoch: 35, Test Accuracy: 0.676750
# Epoch: 36, Train Loss: 0.173174, Train Accuracy: 0.921875
# Epoch: 37, Train Loss: 0.203177, Train Accuracy: 0.921875
# Epoch: 38, Train Loss: 0.186552, Train Accuracy: 0.937500
# Epoch: 39, Train Loss: 0.077432, Train Accuracy: 0.968750
# Epoch: 40, Train Loss: 0.161598, Train Accuracy: 0.921875
# Epoch: 40, Test Accuracy: 0.691875
# Epoch: 41, Train Loss: 0.118623, Train Accuracy: 0.968750
# Epoch: 42, Train Loss: 0.111622, Train Accuracy: 0.968750
# Epoch: 43, Train Loss: 0.083174, Train Accuracy: 0.953125
# Epoch: 44, Train Loss: 0.100101, Train Accuracy: 0.984375
# Epoch: 45, Train Loss: 0.078428, Train Accuracy: 0.968750
# Epoch: 45, Test Accuracy: 0.691875
# Epoch: 46, Train Loss: 0.221630, Train Accuracy: 0.921875
# Epoch: 47, Train Loss: 0.318166, Train Accuracy: 0.906250
# Epoch: 48, Train Loss: 0.082146, Train Accuracy: 0.968750
# Epoch: 49, Train Loss: 0.021083, Train Accuracy: 1.000000
# Epoch: 50, Train Loss: 0.080288, Train Accuracy: 0.968750
# Epoch: 50, Test Accuracy: 0.691875
# Epoch: 51, Train Loss: 0.147545, Train Accuracy: 0.968750
# Epoch: 52, Train Loss: 0.168898, Train Accuracy: 0.921875
# Epoch: 53, Train Loss: 0.103453, Train Accuracy: 0.937500
# Epoch: 54, Train Loss: 0.017703, Train Accuracy: 1.000000
# Epoch: 55, Train Loss: 0.129693, Train Accuracy: 0.953125
# Epoch: 55, Test Accuracy: 0.719750
# Epoch: 56, Train Loss: 0.034264, Train Accuracy: 1.000000
# Epoch: 57, Train Loss: 0.077591, Train Accuracy: 0.968750
# Epoch: 58, Train Loss: 0.195555, Train Accuracy: 0.921875
# Epoch: 59, Train Loss: 0.064306, Train Accuracy: 0.968750
# Epoch: 60, Train Loss: 0.169137, Train Accuracy: 0.953125
# Epoch: 60, Test Accuracy: 0.719750
# Epoch: 61, Train Loss: 0.198956, Train Accuracy: 0.953125
# Epoch: 62, Train Loss: 0.069608, Train Accuracy: 0.968750
# Epoch: 63, Train Loss: 0.029065, Train Accuracy: 1.000000
# Epoch: 64, Train Loss: 0.171608, Train Accuracy: 0.968750
# Epoch: 65, Train Loss: 0.083566, Train Accuracy: 0.968750
# Epoch: 65, Test Accuracy: 0.719750
# Epoch: 66, Train Loss: 0.042176, Train Accuracy: 0.984375
# Epoch: 67, Train Loss: 0.019068, Train Accuracy: 1.000000
# Epoch: 68, Train Loss: 0.113978, Train Accuracy: 0.937500
# Epoch: 69, Train Loss: 0.064364, Train Accuracy: 0.968750
# Epoch: 70, Train Loss: 0.007814, Train Accuracy: 1.000000
# Epoch: 70, Test Accuracy: 0.719750
# Epoch: 71, Train Loss: 0.020366, Train Accuracy: 0.984375
# Epoch: 72, Train Loss: 0.006648, Train Accuracy: 1.000000
# Epoch: 73, Train Loss: 0.075873, Train Accuracy: 0.984375
# Epoch: 74, Train Loss: 0.008575, Train Accuracy: 1.000000
# Epoch: 75, Train Loss: 0.018278, Train Accuracy: 0.984375
# Epoch: 75, Test Accuracy: 0.719750
# Epoch: 76, Train Loss: 0.039402, Train Accuracy: 0.984375
# Epoch: 77, Train Loss: 0.037806, Train Accuracy: 0.984375
# Epoch: 78, Train Loss: 0.038890, Train Accuracy: 0.984375
# Epoch: 79, Train Loss: 0.000727, Train Accuracy: 1.000000
# Epoch: 80, Train Loss: 0.095998, Train Accuracy: 0.984375
# Epoch: 80, Test Accuracy: 0.719875
# Epoch: 81, Train Loss: 0.004276, Train Accuracy: 1.000000
# Epoch: 82, Train Loss: 0.000681, Train Accuracy: 1.000000
# Epoch: 83, Train Loss: 0.011097, Train Accuracy: 1.000000
# Epoch: 84, Train Loss: 0.004426, Train Accuracy: 1.000000
# Epoch: 85, Train Loss: 0.002470, Train Accuracy: 1.000000
# Epoch: 85, Test Accuracy: 0.726000
# Epoch: 86, Train Loss: 0.012099, Train Accuracy: 1.000000
# Epoch: 87, Train Loss: 0.002063, Train Accuracy: 1.000000
# Epoch: 88, Train Loss: 0.004793, Train Accuracy: 1.000000
# Epoch: 89, Train Loss: 0.000797, Train Accuracy: 1.000000
# Epoch: 90, Train Loss: 0.012194, Train Accuracy: 1.000000
# Epoch: 90, Test Accuracy: 0.729500
# Epoch: 91, Train Loss: 0.003132, Train Accuracy: 1.000000
# Epoch: 92, Train Loss: 0.003091, Train Accuracy: 1.000000
# Epoch: 93, Train Loss: 0.020426, Train Accuracy: 0.984375
# Epoch: 94, Train Loss: 0.001214, Train Accuracy: 1.000000

# %% [markdown]
# The ResNet trained from scratch achieves approximately 73% on the test set. This is approximately 8% less than the contrastive learning model, and even slightly less than SimCLR achieves with 1/10 of the data. This shows that self-supervised, contrastive learning provides considerable performance gains by leveraging large amounts of unlabeled data when little labeled data is available.

# %% [markdown]
# ## Conclusion
#
# In this last Laboratory, we have discussed self-supervised contrastive learning and implemented SimCLR as an example method. We have applied it to the STL10 dataset and showed that it can learn generalizable representations that we can use to train simple classification models. With 500 images per label, it achieved an 8% higher accuracy than a similar model solely trained from supervision and performs on par with it when only using a tenth of the labeled data. Our experimental results are limited to a single dataset, but recent works such as [Ting Chen et al.](https://arxiv.org/abs/2006.10029) showed similar trends for larger datasets like ImageNet. Besides the discussed hyperparameters, the size of the model seems to be important in contrastive learning as well. If a lot of unlabeled data is available, larger models can achieve much stronger results and come close to their supervised baselines. Further, there are also approaches for combining contrastive and supervised learning, leading to performance gains beyond supervision (see [Khosla et al.](https://arxiv.org/abs/2004.11362)). Moreover, contrastive learning is not the only approach to self-supervised learning that has come up in the last two years and showed great results. Other methods include distillation-based methods like [BYOL](https://arxiv.org/abs/2006.07733) and redundancy reduction techniques like [Barlow Twins](https://arxiv.org/abs/2103.03230). There is a lot more to explore in the self-supervised domain, and more, impressive steps ahead are to be expected.
